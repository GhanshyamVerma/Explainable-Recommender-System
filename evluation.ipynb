# %%
import pickle
import pandas as pd
import io

# %%
import numpy as np

def apk(actual, predicted, k=10):
    """
    Computes the average precision at k.
    This function computes the average prescision at k between two lists of
    items.
    Parameters
    ----------
    actual : list
             A list of elements that are to be predicted (order doesn't matter)
    predicted : list
                A list of predicted elements (order does matter)
    k : int, optional
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The average precision at k over the input lists
    """
    if len(predicted)>k:
        predicted = predicted[:k]

    score = 0.0
    num_hits = 0.0

    for i,p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i+1.0)

    if not actual:
        return 0.0

    return score / min(len(actual), k)

def mapk(actual, predicted, k=10):
    """
    Computes the mean average precision at k.
    This function computes the mean average prescision at k between two lists
    of lists of items.
    Parameters
    ----------
    actual : list
             A list of lists of elements that are to be predicted
             (order doesn't matter in the lists)
    predicted : list
                A list of lists of predicted elements
                (order matters in the lists)
    k : int, optional
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The mean average precision at k over the input lists
    """
    return np.mean([apk(a,p,k) for a,p in zip(actual, predicted)])

# %%
def _ark(actual: list, predicted: list, k=10) -> int:
    """
    Computes the average recall at k.
    Parameters
    ----------
    actual : list
        A list of actual items to be predicted
    predicted : list
        An ordered list of predicted items
    k : int, default = 10
        Number of predictions to consider
    Returns:
    -------
    score : int
        The average recall at k.
    """
    if len(predicted)>k:
        predicted = predicted[:k]

    score = 0.0
    num_hits = 0.0

    for i,p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i+1.0)

    if not actual:
        return 0.0

    return score / len(actual)

def mark(actual: list, predicted: list, k=10):
    """
    Computes the mean average recall at k.
    Parameters
    ----------
    actual : a list of lists
        Actual items to be predicted
        example: [['A', 'B', 'X'], ['A', 'B', 'Y']]
    predicted : a list of lists
        Ordered predictions
        example: [['X', 'Y', 'Z'], ['X', 'Y', 'Z']]
    Returns:
    -------
        mark: int
            The mean average recall at k (mar@k)
    """
    return np.mean([_ark(a,p,k) for a,p in zip(actual, predicted)])

# %%
def novelty(predicted: list, pop: dict, u: int, n: int):
    """
    Computes the novelty for a list of recommendations
    Parameters
    ----------
    predicted : a list of lists
        Ordered predictions
        example: [['X', 'Y', 'Z'], ['X', 'Y', 'Z']]
    pop: dictionary
        A dictionary of all items alongside of its occurrences counter in the training data
        example: {1198: 893, 1270: 876, 593: 876, 2762: 867}
    u: integer
        The number of users in the training data
    n: integer
        The length of recommended lists per user
    Returns
    ----------
    novelty:
        The novelty of the recommendations in system level
    mean_self_information:
        The novelty of the recommendations in recommended top-N list level
    ----------
    Metric Defintion:
    Zhou, T., Kuscsik, Z., Liu, J. G., Medo, M., Wakeling, J. R., & Zhang, Y. C. (2010).
    Solving the apparent diversity-accuracy dilemma of recommender systems.
    Proceedings of the National Academy of Sciences, 107(10), 4511-4515.
    """
    mean_self_information = []
    k = 0
    for sublist in predicted:
        self_information = 0
        k += 1
        for i in sublist:
            if pop[i]!=0:
                self_information += np.sum(-np.log2(pop[i]/u))
        mean_self_information.append(self_information/n)
    novelty = sum(mean_self_information)/k
    #return novelty, mean_self_information
    return novelty

# %%
def prediction_coverage(predicted: list, catalog: list):
    """
    Computes the prediction coverage for a list of recommendations
    Parameters
    ----------
    predicted : a list of lists
        Ordered predictions
        example: [['X', 'Y', 'Z'], ['X', 'Y', 'Z']]
    catalog: list
        A list of all unique items in the training data
        example: ['A', 'B', 'C', 'X', 'Y', Z]
    Returns
    ----------
    prediction_coverage:
        The prediction coverage of the recommendations as a percent
        rounded to 2 decimal places
    ----------
    Metric Defintion:
    Ge, M., Delgado-Battenfeld, C., & Jannach, D. (2010, September).
    Beyond accuracy: evaluating recommender systems by coverage and serendipity.
    In Proceedings of the fourth ACM conference on Recommender systems (pp. 257-260). ACM.
    """
    predicted_flattened = [p for sublist in predicted for p in sublist]
    unique_predictions = len(set(predicted_flattened))
    prediction_coverage = round(unique_predictions/(len(catalog)* 1.0)*100,2)
    return prediction_coverage

# %%
def catalog_coverage(predicted: list, catalog: list, k: int) -> float:
    """
    Computes the catalog coverage for k lists of recommendations
    Parameters
    ----------
    predicted : a list of lists
        Ordered predictions
        example: [['X', 'Y', 'Z'], ['X', 'Y', 'Z']]
    catalog: list
        A list of all unique items in the training data
        example: ['A', 'B', 'C', 'X', 'Y', Z]
    k: integer
        The number of observed recommendation lists
        which randomly choosed in our offline setup
    Returns
    ----------
    catalog_coverage:
        The catalog coverage of the recommendations as a percent
        rounded to 2 decimal places
    ----------
    Metric Defintion:
    Ge, M., Delgado-Battenfeld, C., & Jannach, D. (2010, September).
    Beyond accuracy: evaluating recommender systems by coverage and serendipity.
    In Proceedings of the fourth ACM conference on Recommender systems (pp. 257-260). ACM.
    """
    sampling = random.choices(predicted, k=k)
    predicted_flattened = [p for sublist in sampling for p in sublist]
    L_predictions = len(set(predicted_flattened))
    catalog_coverage = round(L_predictions/(len(catalog)*1.0)*100,2)
    return catalog_coverage

# %%
real_list = pickle.load(open('./tmp/Challenge_Dataset/real_list.dat', 'rb'))
pred_list = pickle.load(open('./tmp/Challenge_Dataset/pred_list.dat', 'rb'))

# %%
mapk(real_list,pred_list,10)
# Out:
# 0.42674835588609994

# %%
mark(real_list,pred_list,10)
# Out:
# 0.17463211258120756

# %%
articles = pd.read_csv('./Dataset/Published_online_articles.csv')

# %%
df = pd.read_csv('./Dataset/train.csv')

# %%
article_id=articles['article_id'].unique()

# %%
def index_set(s):
    i = 0
    s_map = {}
    for key in s:
        s_map[key] = str(i)
        i+=1
    return s_map

# %%
article_map = index_set(article_id)

# %%
len(article_map.keys())
# Out:
# 71

# %%
#pred_list
idx = []
for tcm_id in df['article_id']:
    idx.append(int(article_map[tcm_id]))
df['article_idx']= idx

# %%
ids = df.article_idx.value_counts()
print(len(ids))
pop = dict(ids)
for i in range(71):
    if i not in pop.keys():
        pop[i]=0
# Out:
# 66

# %%
novelty(pred_list,pop,len(article_id),10)
# Out:
# -1.989277257835678

# %%
catalog = df['article_idx'].unique().tolist()

# %%
prediction_coverage(pred_list, catalog)
# Out:
# 90.91

# %%
import random
catalog_coverage(pred_list, catalog, 10)
# Out:
# 57.58

# %% [markdown]
# ### convert user, article index to real user, article id

# %%
import pickle
best_pred_path = pickle.load(open('./tmp/Challenge_Dataset/best_pred_path.dat', 'rb'))

# %%
def index_set(s):
    i = 0
    s_map = {}
    for key in s:
        s_map[key] = str(i)
        i+=1
    return s_map

# %%
user_id = df['qid'].unique()
article_id=articles['article_id'].unique()
topic_list = []
topics = articles['topic_des_1'].dropna()
for topic in topics:
    t = topic.strip('[').strip(']').strip().split(',')
    for i in range(len(t)):
        j = t[i].strip().replace("'",'')
        if j not in topic_list:
            topic_list.append(j)
topic_tag_list = []
topic_tags = articles['topic_des_2'].dropna()
for tag in topic_tags:
    t = tag.strip('[').strip(']').strip().split(',')
    for i in range(len(t)):
        j = t[i].strip().replace("'",'')
        if j not in topic_tag_list:
            topic_tag_list.append(j)
product_list = []
products = articles['product_des_1'].dropna()
for product in products:
    t = product.strip('[').strip(']').strip().split(',')
    for i in range(len(t)):
        j = t[i].strip().replace("'",'')
        if j not in product_list:
            product_list.append(j)

# %%
user_map = index_set(user_id)
article_map = index_set(article_id)
topic_map = index_set(topic_list)
tag_map = index_set(topic_tag_list)
product_map = index_set(product_list)

# %%
user_map_trans = {v: k for k,v in user_map.items()}
article_map_trans = {v: k for k,v in article_map.items()}
product_map_trans = {v: k for k,v in product_map.items()}
topic_map_trans = {v: k for k,v in topic_map.items()}
tag_map_trans = {v: k for k,v in tag_map.items()}

# %%
best_pred_path_trans={}
for k,v in best_pred_path.items():
    k_d = k
    for i in v:
        j = i[len(i)-1]
        t = 0
        for k in j:
            if k[1]=='user':
                k = list(k)
                k[2]=user_map_trans[str(k[2])]
                k = tuple(k)
                #print(user_map_trans[str(k[2])])
            if k[1]=='article':
                k = list(k)
                k[2]=article_map_trans[str(k[2])]
                k = tuple(k)
            if k[1]=='product':
                k = list(k)
                k[2]=product_map_trans[str(k[2])]
            if k[1]=='topic':
                k = list(k)
                k[2]=topic_map_trans[str(k[2])]
            if k[1]=='tag':
                k = list(k)
                k[2]=tag_map_trans[str(k[2])]
            j[t]=k
            t+=1
        i = list(i)
        i[2]=j
        i = tuple(i)
    best_pred_path_trans[user_map_trans[str(k_d)]]=v

# %%
best_pred_path_trans
# Out:
# {95354290: [(1.4787002,
#    1.0721282,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 4380),
#     ('recommended', 'user', 8779806),
#     ('recommended', 'article', 4150)]),
#   (1.8418957,
#    1.066215,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 9492),
#     ('recommended', 'user', 74756750),
#     ('recommended', 'article', 2105)]),
#   (-0.16660213,
#    1.0656364,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 3246),
#     ('recommended', 'user', 58147318),
#     ('recommended', 'article', 8809)]),
#   (0.70838463,
#    1.067269,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 9237),
#     ('recommended', 'user', 57040101),
#     ('recommended', 'article', 4807)]),
#   (1.8541182,
#    1.0693038,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 8410),
#     ('recommended', 'user', 39394802),
#     ('recommended', 'article', 3755)]),
#   (-1.6295528,
#    1.0745645,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 9922),
#     ('recommended', 'user', 2182320),
#     ('recommended', 'article', 5925)]),
#   (0.72616243,
#    1.0681921,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 5951),
#     ('recommended', 'user', 90913867),
#     ('recommended', 'article', 5326)]),
#   (1.6590147,
#    1.0708861,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 8407),
#     ('recommended', 'user', 90868256),
#     ('recommended', 'article', 7453)]),
#   (-0.5898673,
#    1.0609183,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 7697),
#     ('recommended', 'user', 430968),
#     ('recommended', 'article', 2631)]),
#   (-0.8246026,
#    1.0728098,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 62005676),
#     ('recommended', 'article', 2247)]),
#   (1.530118,
#    1.0671469,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 9492),
#     ('recommended', 'user', 30211627),
#     ('recommended', 'article', 5843)]),
#   (-0.38222367,
#    1.067263,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 8410),
#     ('recommended', 'user', 77127264),
#     ('recommended', 'article', 2229)]),
#   (3.2496653,
#    1.0648073,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 4909),
#     ('recommended', 'user', 56845342),
#     ('recommended', 'article', 5473)]),
#   (-0.4426201,
#    1.0693344,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 5742),
#     ('recommended', 'user', 61445492),
#     ('recommended', 'article', 4326)]),
#   (2.862633,
#    1.0677575,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 9492),
#     ('recommended', 'user', 5802402),
#     ('recommended', 'article', 4434)]),
#   (-0.2481289,
#    1.0533099,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 5172),
#     ('also_response', 'related_article', 25),
#     ('also_response', 'article', 9897)]),
#   (2.264356,
#    1.066594,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 5172),
#     ('recommended', 'user', 20992820),
#     ('recommended', 'article', 2050)]),
#   (-1.8848033,
#    1.065903,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 5172),
#     ('recommended', 'user', 57040101),
#     ('recommended', 'article', 2601)]),
#   (-0.4333904,
#    1.0624135,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 8218),
#     ('recommended', 'user', 16892475),
#     ('recommended', 'article', 7197)]),
#   (-1.4759029,
#    1.0643201,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 8218),
#     ('recommended', 'user', 3957311),
#     ('recommended', 'article', 4458)]),
#   (-0.5701857,
#    1.0430142,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 1226),
#     ('also_response', 'related_article', 24),
#     ('recommended_together', 'article', 2272)])],
#  22451101: [(-0.3562087,
#    1.1169301,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 6379),
#     ['has_product', 'product', 'Mutual funds'],
#     ('has_product', 'article', 2229)]),
#   (1.4423344,
#    1.0697521,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 5925),
#     ('recommended', 'user', 84199855),
#     ('recommended', 'article', 5843)]),
#   (-1.4669694,
#    1.0715663,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 6379),
#     ('recommended', 'user', 88397979),
#     ('recommended', 'article', 8485)]),
#   (-0.6508859,
#    1.0703311,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 5326),
#     ('recommended', 'user', 73807277),
#     ('recommended', 'article', 2272)]),
#   (-0.35638306,
#    1.0684922,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 4434),
#     ('recommended', 'user', 32240400),
#     ('recommended', 'article', 3246)]),
#   (1.778364,
#    1.0677258,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 2631),
#     ('recommended', 'user', 56460666),
#     ('recommended', 'article', 3755)]),
#   (-0.42575482,
#    1.0541645,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 2631),
#     ('also_response', 'related_article', 10),
#     ('also_response', 'article', 7197)]),
#   (1.9333063,
#    1.0685867,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 8218),
#     ('recommended', 'user', 6567408),
#     ('recommended', 'article', 2050)]),
#   (-0.28011423,
#    1.0673019,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 9953),
#     ('recommended', 'user', 20992820),
#     ('recommended', 'article', 8809)]),
#   (-1.8603101,
#    1.0520263,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 5925),
#     ('also_response', 'related_article', 37),
#     ('also_response', 'article', 9922)]),
#   (-1.4786228,
#    1.0657636,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 9469),
#     ('recommended', 'user', 65703510),
#     ('recommended', 'article', 5951)]),
#   (3.1281464,
#    1.064881,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 5326),
#     ('recommended', 'user', 97626415),
#     ('recommended', 'article', 5473)]),
#   (1.0870208,
#    1.0549018,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 4245),
#     ('also_response', 'related_article', 20),
#     ('also_response', 'article', 6184)]),
#   (1.8059214,
#    1.0671393,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 5239),
#     ('recommended', 'user', 4324483),
#     ('recommended', 'article', 2852)]),
#   (-0.250638,
#    1.0665333,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 4380),
#     ('recommended', 'user', 11887764),
#     ('recommended', 'article', 4326)]),
#   (-1.8068811,
#    1.0707343,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 8218),
#     ('recommended', 'user', 54242334),
#     ('recommended', 'article', 1320)]),
#   (1.7503742,
#    1.0623747,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 4434),
#     ('recommended', 'user', 45544986),
#     ('recommended', 'article', 2105)])],
#  21638664: [(-1.3383915,
#    1.0645019,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 3755),
#     ('recommended', 'user', 85459963),
#     ('recommended', 'article', 9953)]),
#   (1.5101782,
#    1.0631509,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 82532248),
#     ('recommended', 'article', 4150)]),
#   (-1.8819766,
#    1.0554308,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 8987),
#     ('also_response', 'related_article', 49),
#     ('also_response', 'article', 5788)]),
#   (-2.348019,
#    1.0649109,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 1561),
#     ('recommended', 'user', 97741551),
#     ('recommended', 'article', 3792)]),
#   (-1.8324484,
#    1.041038,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 4326),
#     ('also_response', 'related_article', 24),
#     ('also_response', 'article', 4126)]),
#   (0.10467865,
#    1.0660235,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 4380),
#     ('recommended', 'user', 32975618),
#     ('recommended', 'article', 9237)]),
#   (-2.0337722,
#    1.059937,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 3246),
#     ('recommended', 'user', 59350046),
#     ('recommended', 'article', 2601)]),
#   (-0.7529707,
#    1.0652496,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 1226),
#     ('recommended', 'user', 89952028),
#     ('recommended', 'article', 2631)]),
#   (2.5014179,
#    1.0659791,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 6379),
#     ('recommended', 'user', 1103855),
#     ('recommended', 'article', 4308)]),
#   (0.65004694,
#    1.0656042,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 1561),
#     ('recommended', 'user', 97772825),
#     ('recommended', 'article', 4807)]),
#   (-1.8985825,
#    1.0641022,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 5951),
#     ('recommended', 'user', 91189938),
#     ('recommended', 'article', 5925)]),
#   (1.9955372,
#    1.0607206,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 2050),
#     ('recommended', 'user', 25589719),
#     ('recommended', 'article', 5259)]),
#   (-0.7588298,
#    1.060776,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 5951),
#     ('recommended', 'user', 64920697),
#     ('recommended', 'article', 9800)]),
#   (-1.9203557,
#    1.0637753,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 2229),
#     ('recommended', 'user', 6567408),
#     ('recommended', 'article', 9469)]),
#   (1.1069247,
#    1.053759,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 8407),
#     ('also_response', 'related_article', 49),
#     ('also_response', 'article', 5172)]),
#   (1.9322929,
#    1.0614654,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 7387),
#     ('recommended', 'user', 21018099),
#     ('recommended', 'article', 2852)]),
#   (-0.8135892,
#    1.0605478,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 7453),
#     ('recommended', 'user', 8703081),
#     ('recommended', 'article', 2272)]),
#   (-0.5344599,
#    1.0473398,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 8921),
#     ('also_response', 'related_article', 26),
#     ('also_response', 'article', 5357)]),
#   (1.9395945,
#    1.0594622,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 5326),
#     ('recommended', 'user', 6507172),
#     ('recommended', 'article', 2105)]),
#   (-0.25979054,
#    1.0473007,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 5326),
#     ('also_response', 'related_article', 4),
#     ('also_response', 'article', 9897)])],
#  80330542: [(-2.1332636,
#    1.0675757,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 8921),
#     ('recommended', 'user', 91189938),
#     ('recommended', 'article', 3792)]),
#   (-2.1001775,
#    1.0517639,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 8921),
#     ('also_response', 'related_article', 41),
#     ('also_response', 'article', 9922)]),
#   (-0.6575924,
#    1.0637465,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 4380),
#     ('recommended', 'user', 90734909),
#     ('recommended', 'article', 8407)]),
#   (-1.9671763,
#    1.0598611,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 5925),
#     ('recommended', 'user', 6022173),
#     ('recommended', 'article', 2601)]),
#   (-0.57930356,
#    1.0672262,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 1226),
#     ('recommended', 'user', 88418079),
#     ('recommended', 'article', 4326)]),
#   (2.7923872,
#    1.0666736,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 2050),
#     ('recommended', 'user', 3769421),
#     ('recommended', 'article', 4434)]),
#   (1.7406768,
#    1.5762199,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 2050),
#     ['has_topic', 'topic', 'Online security'],
#     ('has_topic', 'article', 6184)]),
#   (1.0742451,
#    1.0566285,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 1226),
#     ('also_response', 'related_article', 53),
#     ('also_response', 'article', 5172)]),
#   (-1.7118247,
#    1.064938,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 5925),
#     ('recommended', 'user', 54746273),
#     ('recommended', 'article', 5951)]),
#   (1.8050833,
#    1.0659293,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 4308),
#     ('recommended', 'user', 51972316),
#     ('recommended', 'article', 2105)]),
#   (1.8268383,
#    1.062042,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 5925),
#     ('recommended', 'user', 28072314),
#     ('recommended', 'article', 3755)]),
#   (-1.1141917,
#    1.0640132,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 4807),
#     ('recommended', 'user', 5723995),
#     ('recommended', 'article', 9953)]),
#   (-1.200954,
#    1.0642292,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 4380),
#     ('recommended', 'user', 12039627),
#     ('recommended', 'article', 5239)]),
#   (-0.43664065,
#    1.0617584,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 4275),
#     ('recommended', 'user', 8703081),
#     ('recommended', 'article', 3246)]),
#   (-1.931449,
#    1.0539511,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 4909),
#     ('also_response', 'related_article', 20),
#     ('also_response', 'article', 5788)]),
#   (-1.6605307,
#    1.0609615,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 1561),
#     ('recommended', 'user', 25349443),
#     ('recommended', 'article', 4458)]),
#   (-0.9250117,
#    1.041048,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 2923),
#     ('also_response', 'related_article', 24),
#     ('also_response', 'article', 2247)])],
#  24151170: [(-1.0881104,
#    1.0683478,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 2631),
#     ('recommended', 'user', 90685835),
#     ('recommended', 'article', 9953)]),
#   (1.5498102,
#    1.0668776,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 9237),
#     ('recommended', 'user', 70342129),
#     ('recommended', 'article', 5843)]),
#   (-0.96451765,
#    1.0666133,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 9469),
#     ('recommended', 'user', 60417315),
#     ('recommended', 'article', 5430)]),
#   (-0.24842007,
#    1.0668468,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 9469),
#     ('recommended', 'user', 85770420),
#     ('recommended', 'article', 8809)]),
#   (-1.7068834,
#    1.0676306,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 8218),
#     ('recommended', 'user', 32462819),
#     ('recommended', 'article', 8485)]),
#   (-1.7977501,
#    1.0652204,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 63474557),
#     ('recommended', 'article', 4126)]),
#   (-0.10649948,
#    1.0684444,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 5239),
#     ('recommended', 'user', 55499139),
#     ('recommended', 'article', 1561)]),
#   (1.5394362,
#    1.0652076,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 5951),
#     ('recommended', 'user', 26186777),
#     ('recommended', 'article', 4150)]),
#   (0.6187564,
#    1.0703759,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 5951),
#     ('recommended', 'user', 92051010),
#     ('recommended', 'article', 9492)]),
#   (-2.2381089,
#    1.0697092,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 4380),
#     ('recommended', 'user', 24123480),
#     ('recommended', 'article', 3792)]),
#   (1.5427277,
#    1.0545483,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 4909),
#     ('also_response', 'related_article', 10),
#     ('also_response', 'article', 6184)]),
#   (1.9097445,
#    1.0656528,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 2631),
#     ('recommended', 'user', 55769230),
#     ('recommended', 'article', 2105)]),
#   (-0.7917623,
#    1.0643806,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 8410),
#     ('recommended', 'user', 8130823),
#     ('recommended', 'article', 9800)]),
#   (2.483002,
#    1.0686979,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 8410),
#     ('recommended', 'user', 88418079),
#     ('recommended', 'article', 4308)]),
#   (-0.4333469,
#    1.0537235,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 5473),
#     ('also_response', 'related_article', 10),
#     ('also_response', 'article', 7197)]),
#   (-0.25336134,
#    1.0518949,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 5239),
#     ('also_response', 'related_article', 34),
#     ('also_response', 'article', 9897)]),
#   (-0.43869725,
#    1.0654225,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 2229),
#     ('recommended', 'user', 91554674),
#     ('recommended', 'article', 3246)]),
#   (-1.7731901,
#    1.0622615,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 5259),
#     ('recommended', 'user', 7174105),
#     ('recommended', 'article', 5788)]),
#   (-1.7413276,
#    1.0611244,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 5742),
#     ('recommended', 'user', 29923938),
#     ('recommended', 'article', 5925)]),
#   (-1.99687,
#    1.0615724,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 5326),
#     ('recommended', 'user', 45511368),
#     ('recommended', 'article', 1320)]),
#   (1.9481275,
#    1.06125,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 4326),
#     ('recommended', 'user', 10876983),
#     ('recommended', 'article', 2852)])],
#  56395953: [(-0.47249934,
#    1.0657614,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 5788),
#     ('recommended', 'user', 92051010),
#     ('recommended', 'article', 2631)]),
#   (-1.0293895,
#    1.0654664,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 7697),
#     ('recommended', 'user', 93240481),
#     ('recommended', 'article', 6379)]),
#   (1.5582118,
#    1.06494,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 2272),
#     ('recommended', 'user', 49483396),
#     ('recommended', 'article', 5919)]),
#   (-0.395625,
#    1.0675039,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 4380),
#     ('recommended', 'user', 3833710),
#     ('recommended', 'article', 3246)]),
#   (1.5759721,
#    1.0665381,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 2272),
#     ('recommended', 'user', 70342129),
#     ('recommended', 'article', 5843)]),
#   (1.859423,
#    1.0639247,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 8809),
#     ('recommended', 'user', 49876134),
#     ('recommended', 'article', 2105)]),
#   (1.7164807,
#    1.0660651,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 5259),
#     ('recommended', 'user', 91243393),
#     ('recommended', 'article', 7453)]),
#   (6.727875,
#    1.0505408,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 5259),
#     ('also_response', 'related_article', 13),
#     ('also_response', 'article', 7387)]),
#   (2.8527188,
#    1.0637088,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 5473),
#     ('recommended', 'user', 4452464),
#     ('recommended', 'article', 4434)]),
#   (0.741759,
#    1.0630157,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 4807),
#     ('recommended', 'user', 85459963),
#     ('recommended', 'article', 4909)]),
#   (-1.6424923,
#    1.0666251,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 3792),
#     ('recommended', 'user', 6567408),
#     ('recommended', 'article', 9469)]),
#   (-0.75436926,
#    1.0669268,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 7197),
#     ('recommended', 'user', 3810062),
#     ('recommended', 'article', 2247)]),
#   (-1.3946893,
#    1.0494089,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 5925),
#     ('also_response', 'related_article', 26),
#     ('also_response', 'article', 4458)]),
#   (-0.8423362,
#    1.0671451,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 9492),
#     ('recommended', 'user', 30548561),
#     ('recommended', 'article', 5430)]),
#   (6.6434746,
#    1.0620786,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 7697),
#     ('recommended', 'user', 93914554),
#     ('recommended', 'article', 1226)]),
#   (-0.97630936,
#    1.0617838,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 4807),
#     ('recommended', 'user', 28584938),
#     ('recommended', 'article', 5239)])],
#  77816729: [(0.81749034,
#    1.0635693,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 2601),
#     ('recommended', 'user', 93662097),
#     ('recommended', 'article', 4245)]),
#   (-1.755709,
#    1.0509413,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 2601),
#     ('also_response', 'related_article', 13),
#     ('also_response', 'article', 4126)]),
#   (0.6030935,
#    1.0616739,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 2601),
#     ('recommended', 'user', 6091671),
#     ('recommended', 'article', 9492)]),
#   (-1.0706942,
#    1.0669029,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 6379),
#     ('recommended', 'user', 10792231),
#     ('recommended', 'article', 5239)]),
#   (-0.2672236,
#    1.0663164,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 6379),
#     ('recommended', 'user', 1568403),
#     ('recommended', 'article', 2229)]),
#   (-0.7787416,
#    1.0688616,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 7697),
#     ('recommended', 'user', 24123480),
#     ('recommended', 'article', 2272)]),
#   (-0.58108455,
#    1.0655295,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 4380),
#     ('recommended', 'user', 31100103),
#     ('recommended', 'article', 2631)]),
#   (-0.4128834,
#    1.0702118,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 1320),
#     ('recommended', 'user', 72137232),
#     ('recommended', 'article', 4326)]),
#   (1.5149221,
#    1.0605935,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 5788),
#     ('recommended', 'user', 75256835),
#     ('recommended', 'article', 4150)]),
#   (3.2940512,
#    1.0697502,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 8410),
#     ('recommended', 'user', 28753495),
#     ('recommended', 'article', 5473)]),
#   (-0.4375176,
#    1.0639598,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 5788),
#     ('recommended', 'user', 4974617),
#     ('recommended', 'article', 3246)]),
#   (-2.2464678,
#    1.0653951,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 2105),
#     ('recommended', 'user', 74699348),
#     ('recommended', 'article', 3792)]),
#   (-1.7585393,
#    1.0658598,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 5951),
#     ('recommended', 'user', 51332454),
#     ('recommended', 'article', 5925)]),
#   (2.89402,
#    1.0603783,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 4380),
#     ('recommended', 'user', 6022173),
#     ('recommended', 'article', 4434)]),
#   (1.9118894,
#    1.1767262,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 1226),
#     ['has_product', 'product', 'Stocks'],
#     ('has_product', 'article', 3755)]),
#   (-1.0942988,
#    1.0644106,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 9800),
#     ('recommended', 'user', 88418079),
#     ('recommended', 'article', 9953)]),
#   (2.4499974,
#    1.0629888,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 2247),
#     ('recommended', 'user', 34722158),
#     ('recommended', 'article', 4308)]),
#   (0.34332296,
#    1.0631765,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 5951),
#     ('recommended', 'user', 16565679),
#     ('recommended', 'article', 8218)]),
#   (-0.6096007,
#    1.0605768,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 5430),
#     ('recommended', 'user', 19315048),
#     ('recommended', 'article', 8407)])],
#  75461182: [(-0.3904434,
#    1.0674312,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 6379),
#     ('recommended', 'user', 6567408),
#     ('recommended', 'article', 3246)]),
#   (-0.4530756,
#    1.0661048,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 6379),
#     ('recommended', 'user', 66966434),
#     ('recommended', 'article', 2631)]),
#   (-0.22330464,
#    1.0656796,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 9469),
#     ('recommended', 'user', 49236489),
#     ('recommended', 'article', 8809)]),
#   (1.8854638,
#    1.0635101,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 5430),
#     ('recommended', 'user', 5723995),
#     ('recommended', 'article', 2105)]),
#   (-1.6091565,
#    1.0503098,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 3792),
#     ('also_response', 'related_article', 46),
#     ('also_response', 'article', 4126)]),
#   (-0.71889967,
#    1.057838,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 3792),
#     ('recommended', 'user', 10591106),
#     ('recommended', 'article', 9800)]),
#   (-1.4707173,
#    1.0639334,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 8410),
#     ('recommended', 'user', 26739168),
#     ('recommended', 'article', 5951)]),
#   (1.6900615,
#    1.0491506,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 9237),
#     ('also_response', 'related_article', 27),
#     ('also_response', 'article', 7453)]),
#   (-1.5870682,
#    1.0634534,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 8921),
#     ('recommended', 'user', 69147387),
#     ('recommended', 'article', 5788)]),
#   (-1.3533349,
#    1.0643406,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 5742),
#     ('recommended', 'user', 24151170),
#     ('recommended', 'article', 4458)]),
#   (1.4890766,
#    1.0618274,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 5742),
#     ('recommended', 'user', 8703081),
#     ('recommended', 'article', 5919)]),
#   (2.4690914,
#    1.0610831,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 8218),
#     ('recommended', 'user', 8082604),
#     ('recommended', 'article', 4308)]),
#   (1.5038794,
#    1.0635984,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 7387),
#     ('recommended', 'user', 5802402),
#     ('recommended', 'article', 4150)]),
#   (1.8807395,
#    1.0586593,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 9897),
#     ('recommended', 'user', 6050700),
#     ('recommended', 'article', 2852)]),
#   (0.8449809,
#    1.0605953,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 8218),
#     ('recommended', 'user', 21642285),
#     ('recommended', 'article', 4807)]),
#   (-0.7408298,
#    1.049125,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 4245),
#     ('also_response', 'related_article', 13),
#     ('also_response', 'article', 2247)]),
#   (-1.9219352,
#    1.0591573,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 7387),
#     ('recommended', 'user', 63892357),
#     ('recommended', 'article', 1320)]),
#   (2.040644,
#    1.0649046,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 7387),
#     ('recommended', 'user', 44231110),
#     ('recommended', 'article', 2050)]),
#   (-1.838987,
#    1.0479014,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 7387),
#     ('also_response', 'related_article', 13),
#     ('also_response', 'article', 2601)])],
#  66966434: [(-1.1429628,
#    1.0663787,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 6379),
#     ('recommended', 'user', 88600965),
#     ('recommended', 'article', 4275)]),
#   (2.4731865,
#    1.072285,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 8809),
#     ('recommended', 'user', 6503523),
#     ('recommended', 'article', 4308)]),
#   (1.8508784,
#    1.0704638,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 2105),
#     ('recommended', 'user', 90502),
#     ('recommended', 'article', 2852)]),
#   (-0.67026097,
#    1.069471,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 2601),
#     ('recommended', 'user', 63079092),
#     ('recommended', 'article', 9800)]),
#   (-0.87298614,
#    1.0548841,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 4909),
#     ('also_response', 'related_article', 44),
#     ('also_response', 'article', 2272)]),
#   (-1.1439093,
#    1.065463,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 29459096),
#     ('recommended', 'article', 9953)]),
#   (-0.27895772,
#    1.0444013,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 4150),
#     ('also_response', 'related_article', 24),
#     ('recommended_together', 'article', 9897)]),
#   (-2.0936534,
#    1.066042,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 7453),
#     ('recommended', 'user', 98500679),
#     ('recommended', 'article', 1320)]),
#   (-2.2391741,
#    1.0663007,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 5919),
#     ('recommended', 'user', 33226655),
#     ('recommended', 'article', 3792)]),
#   (2.4777472,
#    1.065249,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 2631),
#     ('recommended', 'user', 8646481),
#     ('recommended', 'article', 2050)]),
#   (-0.48069182,
#    1.0684476,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 1561),
#     ('recommended', 'user', 25033280),
#     ('recommended', 'article', 1073)]),
#   (0.049228884,
#    1.0711632,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 7453),
#     ('recommended', 'user', 6503523),
#     ('recommended', 'article', 9237)]),
#   (1.463368,
#    1.0539927,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 8987),
#     ('also_response', 'related_article', 60),
#     ('also_response', 'article', 6184)]),
#   (-0.43991,
#    1.0673445,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 60544241),
#     ('recommended', 'article', 4326)]),
#   (0.5333802,
#    1.0526193,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 5473),
#     ('also_response', 'related_article', 60),
#     ('also_response', 'article', 2923)]),
#   (-2.226358,
#    1.0431141,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 1226),
#     ('also_response', 'related_article', 24),
#     ('recommended_together', 'article', 9922)]),
#   (3.039058,
#    1.063542,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 4126),
#     ('recommended', 'user', 72980406),
#     ('recommended', 'article', 4434)])],
#  82532248: [(1.864134,
#    1.0647955,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 5742),
#     ('recommended', 'user', 73786710),
#     ('recommended', 'article', 3755)]),
#   (-0.40536386,
#    1.0653871,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 5742),
#     ('recommended', 'user', 96317245),
#     ('recommended', 'article', 4326)]),
#   (-0.31572,
#    1.0641423,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 5742),
#     ('recommended', 'user', 894173),
#     ('recommended', 'article', 2229)]),
#   (-1.7259469,
#    1.0604321,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 4909),
#     ('recommended', 'user', 59427824),
#     ('recommended', 'article', 9469)]),
#   (-2.2519798,
#    1.0634431,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 9953),
#     ('recommended', 'user', 90913867),
#     ('recommended', 'article', 3792)]),
#   (-1.0642655,
#    1.0622587,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 5473),
#     ('recommended', 'user', 8852855),
#     ('recommended', 'article', 6379)]),
#   (-1.7258443,
#    1.0634693,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 8410),
#     ('recommended', 'user', 91243393),
#     ('recommended', 'article', 5925)]),
#   (-1.871654,
#    1.0617967,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 9492),
#     ('recommended', 'user', 95354290),
#     ('recommended', 'article', 4380)]),
#   (-1.7955148,
#    1.0495924,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 4308),
#     ('also_response', 'related_article', 25),
#     ('also_response', 'article', 4126)]),
#   (-0.73012775,
#    1.0649862,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 5172),
#     ('recommended', 'user', 1103855),
#     ('recommended', 'article', 2272)]),
#   (-0.33405918,
#    1.0485015,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 2601),
#     ('also_response', 'related_article', 46),
#     ('also_response', 'article', 1073)]),
#   (1.6679688,
#    1.0597923,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 8921),
#     ('recommended', 'user', 11853271),
#     ('recommended', 'article', 5259)]),
#   (-0.15737286,
#    1.0613371,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 5919),
#     ('recommended', 'user', 94949564),
#     ('recommended', 'article', 8809)]),
#   (-2.206715,
#    1.0572438,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 1561),
#     ('recommended', 'user', 19150580),
#     ('recommended', 'article', 9922)]),
#   (-1.6959761,
#    1.0609959,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 2923),
#     ('recommended', 'user', 8646481),
#     ('recommended', 'article', 8485)]),
#   (0.76449925,
#    1.0609373,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 5951),
#     ('recommended', 'user', 62159474),
#     ('recommended', 'article', 4807)])],
#  60356270: [(-1.1132609,
#    1.0656966,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 2272),
#     ('recommended', 'user', 59660030),
#     ('recommended', 'article', 9953)]),
#   (1.9590971,
#    1.0654873,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 2272),
#     ('recommended', 'user', 84745535),
#     ('recommended', 'article', 8410)]),
#   (-2.0187778,
#    1.0696037,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 4909),
#     ('recommended', 'user', 85962128),
#     ('recommended', 'article', 2601)]),
#   (-2.3060145,
#    1.0602077,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 2105),
#     ('recommended', 'user', 22994233),
#     ('recommended', 'article', 3792)]),
#   (-0.2367747,
#    1.0633522,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 6379),
#     ('recommended', 'user', 67108585),
#     ('recommended', 'article', 8809)]),
#   (1.9163934,
#    1.0655338,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 5925),
#     ('recommended', 'user', 91554674),
#     ('recommended', 'article', 2852)]),
#   (-1.4457123,
#    1.0510786,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 8921),
#     ('also_response', 'related_article', 51),
#     ('also_response', 'article', 4458)]),
#   (-0.16028357,
#    1.0500536,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 6379),
#     ('also_response', 'related_article', 60),
#     ('also_response', 'article', 1561)]),
#   (-0.9228871,
#    1.0593618,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 5239),
#     ('recommended', 'user', 47944661),
#     ('recommended', 'article', 5430)]),
#   (0.2544069,
#    1.0632763,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 4380),
#     ('recommended', 'user', 67422918),
#     ('recommended', 'article', 8218)]),
#   (0.5446429,
#    1.056578,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 4380),
#     ('also_response', 'related_article', 31),
#     ('also_response', 'article', 2923)]),
#   (-1.5129176,
#    1.0630693,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 4909),
#     ('recommended', 'user', 3857212),
#     ('recommended', 'article', 5951)]),
#   (-2.1898015,
#    1.0395783,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 1226),
#     ('also_response', 'related_article', 24),
#     ('recommended_together', 'article', 9922)]),
#   (-1.7357202,
#    1.0620891,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 8485),
#     ('recommended', 'user', 51332454),
#     ('recommended', 'article', 5788)]),
#   (-0.43594393,
#    1.0595493,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 4909),
#     ('recommended', 'user', 25349443),
#     ('recommended', 'article', 3246)])],
#  50953371: [(-1.6764449,
#    1.0621486,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 4275),
#     ('recommended', 'user', 35364364),
#     ('recommended', 'article', 8485)]),
#   (0.7302475,
#    1.0654137,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 4275),
#     ('recommended', 'user', 58813779),
#     ('recommended', 'article', 4807)]),
#   (-1.0287633,
#    1.0656323,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 4909),
#     ('recommended', 'user', 97741551),
#     ('recommended', 'article', 5430)]),
#   (-1.6955656,
#    1.061706,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 6379),
#     ('recommended', 'user', 39419955),
#     ('recommended', 'article', 5951)]),
#   (-0.31365553,
#    1.065633,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 9492),
#     ('recommended', 'user', 74586798),
#     ('recommended', 'article', 8809)]),
#   (-0.97281206,
#    1.062094,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 4909),
#     ('recommended', 'user', 96339085),
#     ('recommended', 'article', 9953)]),
#   (0.56367534,
#    1.0579026,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 71748204),
#     ('recommended', 'article', 2923)]),
#   (1.4944848,
#    1.0625135,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 2631),
#     ('recommended', 'user', 46973312),
#     ('recommended', 'article', 5843)]),
#   (-0.32680443,
#    1.0487702,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 2631),
#     ('also_response', 'related_article', 25),
#     ('also_response', 'article', 9897)]),
#   (0.19696291,
#    1.061305,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 2601),
#     ('recommended', 'user', 28658409),
#     ('recommended', 'article', 8218)]),
#   (0.16894168,
#    1.0651705,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 4308),
#     ('recommended', 'user', 84785102),
#     ('recommended', 'article', 9237)]),
#   (0.8050256,
#    1.0680991,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 9800),
#     ('recommended', 'user', 2182320),
#     ('recommended', 'article', 5326)]),
#   (1.4833308,
#    1.0619991,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 7697),
#     ('recommended', 'user', 8852855),
#     ('recommended', 'article', 5259)]),
#   (-0.25387537,
#    1.0604528,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 1320),
#     ('recommended', 'user', 90523021),
#     ('recommended', 'article', 2229)]),
#   (-1.595885,
#    1.050081,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 2601),
#     ('also_response', 'related_article', 55),
#     ('also_response', 'article', 4458)])],
#  37478512: [(-0.9713388,
#    1.0632857,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 4326),
#     ('recommended', 'user', 61558630),
#     ('recommended', 'article', 6379)]),
#   (2.4127293,
#    1.0564946,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 5843),
#     ('recommended', 'user', 33773489),
#     ('recommended', 'article', 7697)]),
#   (-0.30609548,
#    1.0619286,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 7453),
#     ('recommended', 'user', 74756750),
#     ('recommended', 'article', 1073)]),
#   (-0.5236019,
#    1.0631522,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 2105),
#     ('recommended', 'user', 24204102),
#     ('recommended', 'article', 2631)]),
#   (-0.21486323,
#    1.0600003,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 9953),
#     ('recommended', 'user', 21415256),
#     ('recommended', 'article', 8809)]),
#   (-0.36339858,
#    1.0644504,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 9953),
#     ('recommended', 'user', 1103855),
#     ('recommended', 'article', 2229)]),
#   (1.937766,
#    1.046452,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 4126),
#     ('also_response', 'related_article', 46),
#     ('also_response', 'article', 2852)]),
#   (-0.41950148,
#    1.0500708,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 5788),
#     ('also_response', 'related_article', 51),
#     ('also_response', 'article', 7197)]),
#   (-1.0009726,
#    1.0655671,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 2601),
#     ('recommended', 'user', 54242334),
#     ('recommended', 'article', 5239)]),
#   (6.8477592,
#    1.2929603,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 1226),
#     ['has_product', 'product', 'Fixed income'],
#     ('has_product', 'article', 7387)]),
#   (-0.797816,
#    1.0454404,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 5473),
#     ('also_response', 'related_article', 27),
#     ('also_response', 'article', 2247)]),
#   (-2.1878827,
#    1.0583848,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 3755),
#     ('recommended', 'user', 5674577),
#     ('recommended', 'article', 3792)])],
#  19695842: [(1.8805939,
#    1.0619308,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 9469),
#     ('recommended', 'user', 25416695),
#     ('recommended', 'article', 2852)]),
#   (-1.768345,
#    1.0637983,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 7697),
#     ('recommended', 'user', 93240481),
#     ('recommended', 'article', 5788)]),
#   (0.7141136,
#    1.0632832,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 7387),
#     ('recommended', 'user', 76442608),
#     ('recommended', 'article', 4807)]),
#   (-1.0994996,
#    1.0642917,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 1561),
#     ('recommended', 'user', 10792231),
#     ('recommended', 'article', 9953)]),
#   (-0.44603306,
#    1.063997,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 2272),
#     ('recommended', 'user', 4324483),
#     ('recommended', 'article', 3246)]),
#   (1.4506488,
#    1.0490297,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 2601),
#     ('also_response', 'related_article', 56),
#     ('also_response', 'article', 6184)]),
#   (-1.5596485,
#    1.06296,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 2601),
#     ('recommended', 'user', 30994140),
#     ('recommended', 'article', 5951)]),
#   (-1.874795,
#    1.0589781,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 6050700),
#     ('recommended', 'article', 4380)]),
#   (2.1674793,
#    1.0613109,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 29816351),
#     ('recommended', 'article', 2050)]),
#   (-0.29725412,
#    1.050542,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 8987),
#     ('also_response', 'related_article', 20),
#     ('also_response', 'article', 2229)]),
#   (-1.0756283,
#    1.0592059,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 5919),
#     ('recommended', 'user', 74147321),
#     ('recommended', 'article', 4275)]),
#   (-0.79294646,
#    1.0588787,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 8410),
#     ('recommended', 'user', 45246584),
#     ('recommended', 'article', 9800)]),
#   (1.7941539,
#    1.056769,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 5430),
#     ('recommended', 'user', 63892357),
#     ('recommended', 'article', 2105)])],
#  36756635: [(2.4375339,
#    1.0687096,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 9953),
#     ('recommended', 'user', 44231110),
#     ('recommended', 'article', 2050)]),
#   (-1.6699632,
#    1.0647099,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 7387),
#     ('recommended', 'user', 5802402),
#     ('recommended', 'article', 5925)]),
#   (-0.6754336,
#    1.0679435,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 9469),
#     ('recommended', 'user', 6567408),
#     ('recommended', 'article', 2631)]),
#   (1.600004,
#    1.0534198,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 6379),
#     ('also_response', 'related_article', 54),
#     ('also_response', 'article', 6184)]),
#   (-1.9299815,
#    1.0622199,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 8218),
#     ('recommended', 'user', 49876134),
#     ('recommended', 'article', 5788)]),
#   (-0.43668234,
#    1.0680478,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 3833710),
#     ('recommended', 'article', 3246)]),
#   (1.8115482,
#    1.0644153,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 63090872),
#     ('recommended', 'article', 3755)]),
#   (-1.9505209,
#    1.0615532,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 4909),
#     ('recommended', 'user', 2884473),
#     ('recommended', 'article', 1320)]),
#   (1.6247232,
#    1.0686059,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 4909),
#     ('recommended', 'user', 78282752),
#     ('recommended', 'article', 7453)]),
#   (-0.9982505,
#    1.0628676,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 8410),
#     ('recommended', 'user', 53067043),
#     ('recommended', 'article', 5430)]),
#   (0.6868496,
#    1.0659293,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 8407),
#     ('recommended', 'user', 24151170),
#     ('recommended', 'article', 4245)]),
#   (2.2311976,
#    1.0626574,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 5239),
#     ('recommended', 'user', 86547416),
#     ('recommended', 'article', 7697)]),
#   (-0.3062452,
#    1.0489106,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 5919),
#     ('also_response', 'related_article', 26),
#     ('also_response', 'article', 1073)]),
#   (-0.55980355,
#    1.0651749,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 2923),
#     ('recommended', 'user', 88418079),
#     ('recommended', 'article', 4326)]),
#   (-2.0900738,
#    1.0498319,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 4150),
#     ('also_response', 'related_article', 48),
#     ('also_response', 'article', 9922)]),
#   (-0.35851735,
#    1.0690861,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 8218),
#     ('recommended', 'user', 63079092),
#     ('recommended', 'article', 9897)]),
#   (-0.2115846,
#    1.0486069,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 2601),
#     ('also_response', 'related_article', 13),
#     ('also_response', 'article', 8809)])],
#  49237189: [(1.9679662,
#    1.0649279,
#    [('self_loop', 'user', 49237189),
#     ('recommended', 'article', 5430),
#     ('recommended', 'user', 32240400),
#     ('recommended', 'article', 2852)]),
#   (-0.47922426,
#    1.0659295,
#    [('self_loop', 'user', 49237189),
#     ('recommended', 'article', 5430),
#     ('recommended', 'user', 11887764),
#     ('recommended', 'article', 4326)]),
#   (1.6497442,
#    1.0648293,
#    [('self_loop', 'user', 49237189),
#     ('recommended', 'article', 2631),
#     ('recommended', 'user', 7357379),
#     ('recommended', 'article', 5919)]),
#   (-1.8071843,
#    1.0681926,
#    [('self_loop', 'user', 49237189),
#     ('recommended', 'article', 5951),
#     ('recommended', 'user', 84199855),
#     ('recommended', 'article', 5925)]),
#   (-1.7925957,
#    1.0639025,
#    [('self_loop', 'user', 49237189),
#     ('recommended', 'article', 8485),
# ...
#   (-1.0491282,
#    1.0658613,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 8485),
#     ('recommended', 'user', 92051010),
#     ('recommended', 'article', 5239)]),
#   (2.852041,
#    1.0680412,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 9953),
#     ('recommended', 'user', 65362127),
#     ('recommended', 'article', 4434)]),
#   (1.563972,
#    1.062611,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 1226),
#     ('recommended', 'user', 49553283),
#     ('recommended', 'article', 5259)]),
#   (0.026740162,
#    1.0633307,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 5925),
#     ('recommended', 'user', 96317245),
#     ('recommended', 'article', 1561)]),
#   (-0.4191317,
#    1.0632792,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 5925),
#     ('recommended', 'user', 34722158),
#     ('recommended', 'article', 3246)]),
#   (1.3774661,
#    1.0615914,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 1073),
#     ('recommended', 'user', 10876983),
#     ('recommended', 'article', 6184)]),
#   (-0.19436942,
#    1.0637089,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 2105),
#     ('recommended', 'user', 14853630),
#     ('recommended', 'article', 8809)]),
#   (-2.1495693,
#    1.0529891,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 4909),
#     ('also_response', 'related_article', 36),
#     ('also_response', 'article', 9922)]),
#   (-1.7883186,
#    1.0710853,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 54242334),
#     ('recommended', 'article', 4380)]),
#   (-0.82323503,
#    1.0619633,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 8921),
#     ('recommended', 'user', 77816729),
#     ('recommended', 'article', 2247)]),
#   (2.3076515,
#    1.0647386,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 8852855),
#     ('recommended', 'article', 7697)]),
#   (0.6295663,
#    1.0625583,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 2923),
#     ('recommended', 'user', 75754754),
#     ('recommended', 'article', 9492)]),
#   (0.17877838,
#    1.062785,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 8485),
#     ('recommended', 'user', 53067043),
#     ('recommended', 'article', 9237)])],
#  4974617: [(1.1282456,
#    1.0671105,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 2631),
#     ('recommended', 'user', 75404459),
#     ('recommended', 'article', 5172)]),
#   (-1.6373235,
#    1.066751,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 4380),
#     ('recommended', 'user', 91243393),
#     ('recommended', 'article', 8485)]),
#   (-1.6316592,
#    1.067792,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 6379),
#     ('recommended', 'user', 8779806),
#     ('recommended', 'article', 5925)]),
#   (2.3773055,
#    1.0655417,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 4807),
#     ('recommended', 'user', 3857212),
#     ('recommended', 'article', 7697)]),
#   (-1.625024,
#    1.0682958,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 9237),
#     ('recommended', 'user', 13413877),
#     ('recommended', 'article', 5951)]),
#   (1.472228,
#    1.0662472,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 4909),
#     ('recommended', 'user', 8852855),
#     ('recommended', 'article', 5259)]),
#   (-0.34457362,
#    1.0657617,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 3792),
#     ('recommended', 'user', 4324483),
#     ('recommended', 'article', 2229)]),
#   (-1.0200685,
#    1.0660452,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 5723995),
#     ('recommended', 'article', 9953)]),
#   (1.896925,
#    1.0656784,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 83679709),
#     ('recommended', 'article', 2852)]),
#   (0.7457724,
#    1.0644664,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 4275),
#     ('recommended', 'user', 75754754),
#     ('recommended', 'article', 4245)]),
#   (-0.2814597,
#    1.0628252,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 8921),
#     ('recommended', 'user', 58147318),
#     ('recommended', 'article', 8809)]),
#   (3.3431277,
#    1.0644236,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 5843),
#     ('recommended', 'user', 91554674),
#     ('recommended', 'article', 5473)]),
#   (1.8763046,
#    1.0607215,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 9800),
#     ('recommended', 'user', 50953371),
#     ('recommended', 'article', 2105)]),
#   (-1.033074,
#    1.0667603,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 7197),
#     ('recommended', 'user', 2998426),
#     ('recommended', 'article', 5239)]),
#   (-0.278525,
#    1.0520281,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 4458),
#     ('also_response', 'related_article', 55),
#     ('also_response', 'article', 9897)]),
#   (-0.85354185,
#    1.0618371,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 7453),
#     ('recommended', 'user', 31443292),
#     ('recommended', 'article', 2247)]),
#   (-1.6200287,
#    1.0644614,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 7453),
#     ('recommended', 'user', 9140781),
#     ('recommended', 'article', 9469)])],
#  53218502: [(0.052404616,
#    1.0507655,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 5919),
#     ('also_response', 'related_article', 13),
#     ('also_response', 'article', 9237)]),
#   (-0.40797502,
#    1.0637552,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 2272),
#     ('recommended', 'user', 8130823),
#     ('recommended', 'article', 4326)]),
#   (-0.9058418,
#    1.051573,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 2272),
#     ('also_response', 'related_article', 26),
#     ('also_response', 'article', 2247)]),
#   (0.7538853,
#    1.0649065,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 2272),
#     ('recommended', 'user', 55348534),
#     ('recommended', 'article', 4245)]),
#   (1.9270283,
#    1.0676602,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 3792),
#     ('recommended', 'user', 53349469),
#     ('recommended', 'article', 2105)]),
#   (1.7255685,
#    1.069528,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 9922),
#     ('recommended', 'user', 72137232),
#     ('recommended', 'article', 7453)]),
#   (-1.0873879,
#    1.0666275,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 1320),
#     ('recommended', 'user', 2998426),
#     ('recommended', 'article', 5239)]),
#   (-1.1278094,
#    1.0626262,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 58839997),
#     ('recommended', 'article', 4275)]),
#   (-0.21242891,
#    1.0502334,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 8987),
#     ('also_response', 'related_article', 26),
#     ('also_response', 'article', 1561)]),
#   (-1.7077311,
#    1.0662831,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 9922),
#     ('recommended', 'user', 58813779),
#     ('recommended', 'article', 8485)]),
#   (-1.9552467,
#    1.0626792,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 2050),
#     ('recommended', 'user', 8130823),
#     ('recommended', 'article', 2601)]),
#   (2.4795392,
#    1.0664837,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 4126),
#     ('recommended', 'user', 6503523),
#     ('recommended', 'article', 4308)]),
#   (-1.5941384,
#    1.05958,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 2050),
#     ('recommended', 'user', 10591106),
#     ('recommended', 'article', 4458)]),
#   (2.458082,
#    1.0577327,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 5326),
#     ('recommended', 'user', 93058502),
#     ('recommended', 'article', 7697)]),
#   (-1.6852647,
#    1.0674748,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 5259),
#     ('recommended', 'user', 13413877),
#     ('recommended', 'article', 9469)]),
#   (1.5320368,
#    1.0573262,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 4380),
#     ('recommended', 'user', 16612237),
#     ('recommended', 'article', 4150)]),
#   (-1.0036342,
#    1.0627568,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 6379),
#     ('recommended', 'user', 62159474),
#     ('recommended', 'article', 5430)]),
#   (-0.5023172,
#    1.0505375,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 6379),
#     ('also_response', 'related_article', 25),
#     ('also_response', 'article', 7197)]),
#   (-0.63783526,
#    1.0622345,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 9897),
#     ('recommended', 'user', 93928051),
#     ('recommended', 'article', 2631)])],
#  5723995: [(-1.9378352,
#    1.0702279,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 2247004),
#     ('recommended', 'article', 4380)]),
#   (2.976312,
#    1.0651163,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 9953),
#     ('recommended', 'user', 63711636),
#     ('recommended', 'article', 4434)]),
#   (-0.8040454,
#    1.062228,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 4909),
#     ('recommended', 'user', 85837),
#     ('recommended', 'article', 9800)]),
#   (1.4937638,
#    1.0702844,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 8485),
#     ('recommended', 'user', 85962128),
#     ('recommended', 'article', 5843)]),
#   (-0.37258744,
#    1.0515324,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 5919),
#     ('also_response', 'related_article', 8),
#     ('also_response', 'article', 1073)]),
#   (-0.70116013,
#    1.062864,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 1226),
#     ('recommended', 'user', 27079591),
#     ('recommended', 'article', 8407)]),
#   (-1.57775,
#    1.0662693,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 8987),
#     ('recommended', 'user', 84199855),
#     ('recommended', 'article', 5925)]),
#   (1.9913503,
#    1.1752758,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 1226),
#     ['has_product', 'product', 'Stocks'],
#     ('has_product', 'article', 3755)]),
#   (0.6811216,
#    1.0671332,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 9469),
#     ('recommended', 'user', 93240481),
#     ('recommended', 'article', 5326)]),
#   (-0.6112165,
#    1.0641887,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 4150),
#     ('recommended', 'user', 33098763),
#     ('recommended', 'article', 2631)]),
#   (0.5369199,
#    1.0649341,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 2105),
#     ('recommended', 'user', 72193736),
#     ('recommended', 'article', 2923)]),
#   (-1.9989276,
#    1.0620829,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 2105),
#     ('recommended', 'user', 19264012),
#     ('recommended', 'article', 1320)]),
#   (-0.7265768,
#    1.0634227,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 5788),
#     ('recommended', 'user', 63423394),
#     ('recommended', 'article', 2272)]),
#   (1.8964925,
#    1.0622401,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 1561),
#     ('recommended', 'user', 26211712),
#     ('recommended', 'article', 2852)]),
#   (2.4767935,
#    1.0649378,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 5951),
#     ('recommended', 'user', 16931744),
#     ('recommended', 'article', 4308)]),
#   (-0.50634396,
#    1.0527108,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 5742),
#     ('also_response', 'related_article', 10),
#     ('also_response', 'article', 7197)]),
#   (-1.049521,
#    1.0604274,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 4807),
#     ('recommended', 'user', 11946051),
#     ('recommended', 'article', 5239)]),
#   (-1.5429872,
#    1.0705625,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 5742),
#     ('recommended', 'user', 2247004),
#     ('recommended', 'article', 4458)]),
#   (2.329335,
#    1.0624528,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 2229),
#     ('recommended', 'user', 6507172),
#     ('recommended', 'article', 7697)]),
#   (1.5268136,
#    1.0615417,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 7453),
#     ('recommended', 'user', 21890591),
#     ('recommended', 'article', 5259)])],
#  49710303: [(-1.1344182,
#    1.0638677,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 5925),
#     ('recommended', 'user', 35156684),
#     ('recommended', 'article', 4275)]),
#   (1.8444943,
#    1.061517,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 5925),
#     ('recommended', 'user', 94804282),
#     ('recommended', 'article', 5259)]),
#   (-0.85766155,
#    1.066339,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 5925),
#     ('recommended', 'user', 11887764),
#     ('recommended', 'article', 2272)]),
#   (1.6055251,
#    1.0642731,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 6379),
#     ('recommended', 'user', 44268505),
#     ('recommended', 'article', 5843)]),
#   (-0.25466886,
#    1.0623537,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 5951),
#     ('recommended', 'user', 11887764),
#     ('recommended', 'article', 2229)]),
#   (-0.18795452,
#    1.0628272,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 9800),
#     ('recommended', 'user', 88600965),
#     ('recommended', 'article', 8809)]),
#   (-0.9183986,
#    1.048576,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 2852),
#     ('also_response', 'related_article', 4),
#     ('also_response', 'article', 2247)]),
#   (-1.1946539,
#    1.0577826,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 4308),
#     ('recommended', 'user', 30847606),
#     ('recommended', 'article', 5239)]),
#   (-0.69828683,
#    1.062806,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 1561),
#     ('recommended', 'user', 90734909),
#     ('recommended', 'article', 2631)]),
#   (-1.2835133,
#    1.0598146,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 7453),
#     ('recommended', 'user', 11574417),
#     ('recommended', 'article', 9953)]),
#   (-2.3741124,
#    1.0615716,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 2852),
#     ('recommended', 'user', 12039627),
#     ('recommended', 'article', 3792)]),
#   (1.9461607,
#    1.0636642,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 7697),
#     ('recommended', 'user', 62159474),
#     ('recommended', 'article', 2105)]),
#   (-2.5174644,
#    1.0606748,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 7697),
#     ('recommended', 'user', 93914554),
#     ('recommended', 'article', 8921)]),
#   (-1.8042214,
#    1.039383,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 9237),
#     ('also_response', 'related_article', 24),
#     ('also_response', 'article', 4126)]),
#   (0.8106197,
#    1.0656168,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 2050),
#     ('recommended', 'user', 32975618),
#     ('recommended', 'article', 4245)]),
#   (-0.548309,
#    1.0475138,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 2050),
#     ('also_response', 'related_article', 64),
#     ('also_response', 'article', 5357)]),
#   (-0.2521118,
#    1.0394177,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 4326),
#     ('also_response', 'related_article', 24),
#     ('recommended_together', 'article', 9897)]),
#   (0.5120185,
#    1.0657526,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 5951),
#     ('recommended', 'user', 30087646),
#     ('recommended', 'article', 2923)])]}
