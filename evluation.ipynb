# %%
import pickle
import pandas as pd
import io

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir("/content/drive/My Drive/google colab/fidelity/KG-RL_Rec_Sys/")
# !ls
# Out:
# common_words_generate.ipynb  kg_env.py		  __pycache__
# Dataset			     KG_RL_Rec_Sys.ipynb  tmp
# data_utils.py		     knowledge_graph.py   transe_model.py
# evluation.ipynb		     processing.ipynb	  utils.py

# %%
import numpy as np

def apk(actual, predicted, k=10):
    """
    Computes the average precision at k.
    This function computes the average prescision at k between two lists of
    items.
    Parameters
    ----------
    actual : list
             A list of elements that are to be predicted (order doesn't matter)
    predicted : list
                A list of predicted elements (order does matter)
    k : int, optional
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The average precision at k over the input lists
    """
    if len(predicted)>k:
        predicted = predicted[:k]

    score = 0.0
    num_hits = 0.0

    for i,p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i+1.0)

    if not actual:
        return 0.0

    return score / min(len(actual), k)

def mapk(actual, predicted, k=10):
    """
    Computes the mean average precision at k.
    This function computes the mean average prescision at k between two lists
    of lists of items.
    Parameters
    ----------
    actual : list
             A list of lists of elements that are to be predicted
             (order doesn't matter in the lists)
    predicted : list
                A list of lists of predicted elements
                (order matters in the lists)
    k : int, optional
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The mean average precision at k over the input lists
    """
    return np.mean([apk(a,p,k) for a,p in zip(actual, predicted)])

# %%
def _ark(actual: list, predicted: list, k=10) -> int:
    """
    Computes the average recall at k.
    Parameters
    ----------
    actual : list
        A list of actual items to be predicted
    predicted : list
        An ordered list of predicted items
    k : int, default = 10
        Number of predictions to consider
    Returns:
    -------
    score : int
        The average recall at k.
    """
    if len(predicted)>k:
        predicted = predicted[:k]

    score = 0.0
    num_hits = 0.0

    for i,p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i+1.0)

    if not actual:
        return 0.0

    return score / len(actual)

def mark(actual: list, predicted: list, k=10):
    """
    Computes the mean average recall at k.
    Parameters
    ----------
    actual : a list of lists
        Actual items to be predicted
        example: [['A', 'B', 'X'], ['A', 'B', 'Y']]
    predicted : a list of lists
        Ordered predictions
        example: [['X', 'Y', 'Z'], ['X', 'Y', 'Z']]
    Returns:
    -------
        mark: int
            The mean average recall at k (mar@k)
    """
    return np.mean([_ark(a,p,k) for a,p in zip(actual, predicted)])

# %%
def novelty(predicted: list, pop: dict, u: int, n: int):
    """
    Computes the novelty for a list of recommendations
    Parameters
    ----------
    predicted : a list of lists
        Ordered predictions
        example: [['X', 'Y', 'Z'], ['X', 'Y', 'Z']]
    pop: dictionary
        A dictionary of all items alongside of its occurrences counter in the training data
        example: {1198: 893, 1270: 876, 593: 876, 2762: 867}
    u: integer
        The number of users in the training data
    n: integer
        The length of recommended lists per user
    Returns
    ----------
    novelty:
        The novelty of the recommendations in system level
    mean_self_information:
        The novelty of the recommendations in recommended top-N list level
    ----------
    Metric Defintion:
    Zhou, T., Kuscsik, Z., Liu, J. G., Medo, M., Wakeling, J. R., & Zhang, Y. C. (2010).
    Solving the apparent diversity-accuracy dilemma of recommender systems.
    Proceedings of the National Academy of Sciences, 107(10), 4511-4515.
    """
    mean_self_information = []
    k = 0
    for sublist in predicted:
        self_information = 0
        k += 1
        for i in sublist:
            if pop[i]!=0:
                self_information += np.sum(-np.log2(pop[i]/u))
        mean_self_information.append(self_information/n)
    novelty = sum(mean_self_information)/k
    #return novelty, mean_self_information
    return novelty

# %%
def prediction_coverage(predicted: list, catalog: list):
    """
    Computes the prediction coverage for a list of recommendations
    Parameters
    ----------
    predicted : a list of lists
        Ordered predictions
        example: [['X', 'Y', 'Z'], ['X', 'Y', 'Z']]
    catalog: list
        A list of all unique items in the training data
        example: ['A', 'B', 'C', 'X', 'Y', Z]
    Returns
    ----------
    prediction_coverage:
        The prediction coverage of the recommendations as a percent
        rounded to 2 decimal places
    ----------
    Metric Defintion:
    Ge, M., Delgado-Battenfeld, C., & Jannach, D. (2010, September).
    Beyond accuracy: evaluating recommender systems by coverage and serendipity.
    In Proceedings of the fourth ACM conference on Recommender systems (pp. 257-260). ACM.
    """
    predicted_flattened = [p for sublist in predicted for p in sublist]
    unique_predictions = len(set(predicted_flattened))
    prediction_coverage = round(unique_predictions/(len(catalog)* 1.0)*100,2)
    return prediction_coverage

# %%
def catalog_coverage(predicted: list, catalog: list, k: int) -> float:
    """
    Computes the catalog coverage for k lists of recommendations
    Parameters
    ----------
    predicted : a list of lists
        Ordered predictions
        example: [['X', 'Y', 'Z'], ['X', 'Y', 'Z']]
    catalog: list
        A list of all unique items in the training data
        example: ['A', 'B', 'C', 'X', 'Y', Z]
    k: integer
        The number of observed recommendation lists
        which randomly choosed in our offline setup
    Returns
    ----------
    catalog_coverage:
        The catalog coverage of the recommendations as a percent
        rounded to 2 decimal places
    ----------
    Metric Defintion:
    Ge, M., Delgado-Battenfeld, C., & Jannach, D. (2010, September).
    Beyond accuracy: evaluating recommender systems by coverage and serendipity.
    In Proceedings of the fourth ACM conference on Recommender systems (pp. 257-260). ACM.
    """
    sampling = random.choices(predicted, k=k)
    predicted_flattened = [p for sublist in sampling for p in sublist]
    L_predictions = len(set(predicted_flattened))
    catalog_coverage = round(L_predictions/(len(catalog)*1.0)*100,2)
    return catalog_coverage

# %%
real_list = pickle.load(open('./tmp/Challenge_Dataset/real_list.dat', 'rb'))
pred_list = pickle.load(open('./tmp/Challenge_Dataset/pred_list.dat', 'rb'))

# %%
mapk(real_list,pred_list,10)
# Out:
# 0.4285383597883598

# %%
mark(real_list,pred_list,10)
# Out:
# 0.17533574472262184

# %%
articles = pd.read_csv('./Dataset/articles.csv')

# %%
df = pd.read_csv('./Dataset/train.csv')

# %%
article_id=articles['article_id'].unique()

# %%
def index_set(s):
    i = 0
    s_map = {}
    for key in s:
        s_map[key] = str(i)
        i+=1
    return s_map

# %%
article_map = index_set(article_id)

# %%
len(article_map.keys())
# Out:
# 71

# %%
#pred_list
idx = []
for tcm_id in df['article_id']:
    idx.append(int(article_map[tcm_id]))
df['article_idx']= idx

# %%
ids = df.article_idx.value_counts()
print(len(ids))
pop = dict(ids)
for i in range(71):
    if i not in pop.keys():
        pop[i]=0
# Out:
# 66

# %%
novelty(pred_list,pop,len(article_id),10)
# Out:
# -1.9858119056523102

# %%
catalog = df['article_idx'].unique().tolist()

# %%
prediction_coverage(pred_list, catalog)
# Out:
# 89.39

# %%
import random
catalog_coverage(pred_list, catalog, 10)
# Out:
# 56.06

# %% [markdown]
# ### convert user, article index to real user, article id

# %%
import pickle
best_pred_path = pickle.load(open('./tmp/Challenge_Dataset/best_pred_path.dat', 'rb'))

# %%
def index_set(s):
    i = 0
    s_map = {}
    for key in s:
        s_map[key] = str(i)
        i+=1
    return s_map

# %%
user_id = df['qid'].unique()
article_id=articles['article_id'].unique()
topic_list = []
topics = articles['topic'].dropna()
for topic in topics:
    t = topic.strip('[').strip(']').strip().split(',')
    for i in range(len(t)):
        j = t[i].strip().replace("'",'')
        if j not in topic_list:
            topic_list.append(j)
topic_tag_list = []
topic_tags = articles['vstopic'].dropna()
for tag in topic_tags:
    t = tag.strip('[').strip(']').strip().split(',')
    for i in range(len(t)):
        j = t[i].strip().replace("'",'')
        if j not in topic_tag_list:
            topic_tag_list.append(j)
product_list = []
products = articles['product'].dropna()
for product in products:
    t = product.strip('[').strip(']').strip().split(',')
    for i in range(len(t)):
        j = t[i].strip().replace("'",'')
        if j not in product_list:
            product_list.append(j)

# %%
user_map = index_set(user_id)
article_map = index_set(article_id)
topic_map = index_set(topic_list)
tag_map = index_set(topic_tag_list)
product_map = index_set(product_list)

# %%
user_map_trans = {v: k for k,v in user_map.items()}
article_map_trans = {v: k for k,v in article_map.items()}
product_map_trans = {v: k for k,v in product_map.items()}
topic_map_trans = {v: k for k,v in topic_map.items()}
tag_map_trans = {v: k for k,v in tag_map.items()}

# %%
best_pred_path_trans={}
for k,v in best_pred_path.items():
    k_d = k
    for i in v:
        j = i[len(i)-1]
        t = 0
        for k in j:
            if k[1]=='user':
                k = list(k)
                k[2]=user_map_trans[str(k[2])]
                k = tuple(k)
                #print(user_map_trans[str(k[2])])
            if k[1]=='article':
                k = list(k)
                k[2]=article_map_trans[str(k[2])]
                k = tuple(k)
            if k[1]=='product':
                k = list(k)
                k[2]=product_map_trans[str(k[2])]
            if k[1]=='topic':
                k = list(k)
                k[2]=topic_map_trans[str(k[2])]
            if k[1]=='tag':
                k = list(k)
                k[2]=tag_map_trans[str(k[2])]
            j[t]=k
            t+=1
        i = list(i)
        i[2]=j
        i = tuple(i)
    best_pred_path_trans[user_map_trans[str(k_d)]]=v

# %%
best_pred_path_trans
# Out:
# {95354290: [(0.5607989,
#    1.0751053,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('recommended', 'user', 90868256),
#     ('recommended', 'article', 'tcm:526-707567')]),
#   (1.9893385,
#    1.0713649,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('recommended', 'user', 61258577),
#     ('recommended', 'article', 'tcm:526-681575')]),
#   (-0.24286696,
#    1.071164,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-228258'),
#     ('recommended', 'user', 69530129),
#     ('recommended', 'article', 'tcm:526-261006')]),
#   (1.6353227,
#    1.0665469,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-228258'),
#     ('recommended', 'user', 33424908),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (-0.7124439,
#    1.066412,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-228258'),
#     ('recommended', 'user', 90685835),
#     ('recommended', 'article', 'tcm:526-674187')]),
#   (1.3822533,
#    1.0710522,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 65393045),
#     ('recommended', 'article', 'tcm:526-153236')]),
#   (-0.45123762,
#    1.065971,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-653510'),
#     ('recommended', 'user', 85770420),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (-0.099195205,
#    1.0671835,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-149043'),
#     ('recommended', 'user', 30994140),
#     ('recommended', 'article', 'tcm:526-18025')]),
#   (1.8188492,
#    1.0648203,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-259315'),
#     ('recommended', 'user', 45511368),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (-0.9005941,
#    1.0628577,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-249037'),
#     ('recommended', 'user', 12023267),
#     ('recommended', 'article', 'tcm:526-249921')]),
#   (0.30019405,
#    1.070707,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-93195'),
#     ('recommended', 'user', 54242334),
#     ('recommended', 'article', 'tcm:526-10838')]),
#   (2.590102,
#    1.0661714,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-231792'),
#     ('recommended', 'user', 2657375),
#     ('recommended', 'article', 'tcm:526-654768')]),
#   (-0.6047127,
#    1.0535367,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-653510'),
#     ('also_response', 'related_article', 10),
#     ('also_response', 'article', 'tcm:526-273898')]),
#   (-1.626832,
#    1.0698632,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-149043'),
#     ('recommended', 'user', 20992820),
#     ('recommended', 'article', 'tcm:526-199040')]),
#   (3.1941257,
#    1.065272,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('recommended', 'user', 73673636),
#     ('recommended', 'article', 'tcm:526-784445')]),
#   (-0.037651975,
#    1.0525925,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-244935'),
#     ('also_response', 'related_article', 34),
#     ('also_response', 'article', 'tcm:526-682576')]),
#   (1.5193173,
#    1.042881,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-249037'),
#     ('also_response', 'related_article', 24),
#     ('also_response', 'article', 'tcm:526-80807')]),
#   (-1.740997,
#    1.065703,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-712788'),
#     ('recommended', 'user', 90913867),
#     ('recommended', 'article', 'tcm:526-12167')]),
#   (-1.2727909,
#    1.0548546,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-707527'),
#     ('also_response', 'related_article', 43),
#     ('also_response', 'article', 'tcm:526-346380')]),
#   (-0.79036754,
#    1.0705723,
#    [('self_loop', 'user', 95354290),
#     ('recommended', 'article', 'tcm:526-10787'),
#     ('recommended', 'user', 72137232),
#     ('recommended', 'article', 'tcm:526-40469')])],
#  22451101: [(-0.31124502,
#    1.0723578,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 78282752),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (1.5781574,
#    1.0677273,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 96126295),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (1.7438202,
#    1.0675111,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-712788'),
#     ('recommended', 'user', 13413877),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (0.9942236,
#    1.0636506,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-674187'),
#     ('recommended', 'user', 14394841),
#     ('recommended', 'article', 'tcm:526-191289')]),
#   (-0.09913753,
#    1.0693572,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 1103855),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (0.10409503,
#    1.067412,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-22867'),
#     ('recommended', 'user', 74756750),
#     ('recommended', 'article', 'tcm:526-249037')]),
#   (1.9120072,
#    1.0692551,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-149043'),
#     ('recommended', 'user', 49641139),
#     ('recommended', 'article', 'tcm:526-681575')]),
#   (-1.4538392,
#    1.0690941,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-199040'),
#     ('recommended', 'user', 92051010),
#     ('recommended', 'article', 'tcm:526-228258')]),
#   (1.310181,
#    1.066404,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-231792'),
#     ('recommended', 'user', 9696139),
#     ('recommended', 'article', 'tcm:526-153236')]),
#   (1.1852834,
#    1.0605524,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-199040'),
#     ('recommended', 'user', 16612237),
#     ('recommended', 'article', 'tcm:526-276414')]),
#   (-0.20285046,
#    1.0697223,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 89952028),
#     ('recommended', 'article', 'tcm:526-688510')]),
#   (-1.2771062,
#    1.0702343,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-782343'),
#     ('recommended', 'user', 8779806),
#     ('recommended', 'article', 'tcm:526-684643')]),
#   (1.7918552,
#    1.0637486,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-782343'),
#     ('also_response', 'related_article', 23),
#     ('also_response', 'article', 'tcm:526-679101')]),
#   (1.4517087,
#    1.0653111,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 58996382),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (-0.8085673,
#    1.0520219,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-654768'),
#     ('also_response', 'related_article', 28),
#     ('also_response', 'article', 'tcm:526-249921')]),
#   (6.188593,
#    1.0507181,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-653510'),
#     ('also_response', 'related_article', 41),
#     ('also_response', 'article', 'tcm:526-10787')]),
#   (-1.4956688,
#    1.0590814,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-52560'),
#     ('recommended', 'user', 16612237),
#     ('recommended', 'article', 'tcm:526-385364')]),
#   (-1.6126264,
#    1.0432105,
#    [('self_loop', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-712788'),
#     ('also_response', 'related_article', 24),
#     ('recommended_together', 'article', 'tcm:526-259315')])],
#  21638664: [(0.5020458,
#    1.0652193,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-237984'),
#     ('recommended', 'user', 88418079),
#     ('recommended', 'article', 'tcm:526-707567')]),
#   (-1.7885596,
#    1.0533369,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-237984'),
#     ('also_response', 'related_article', 43),
#     ('also_response', 'article', 'tcm:526-385364')]),
#   (-1.9137919,
#    1.0492764,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-248966'),
#     ('also_response', 'related_article', 41),
#     ('also_response', 'article', 'tcm:526-258965')]),
#   (1.9568763,
#    1.0652906,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-52560'),
#     ('recommended', 'user', 90502),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (-1.9156891,
#    1.0626222,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-149043'),
#     ('recommended', 'user', 8130823),
#     ('recommended', 'article', 'tcm:526-12167')]),
#   (-1.087935,
#    1.0631728,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 97626415),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (-1.9951146,
#    1.0653603,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-22867'),
#     ('recommended', 'user', 16099560),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (1.5959712,
#    1.0617152,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-52560'),
#     ('recommended', 'user', 93914554),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (0.15718122,
#    1.0594844,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-228258'),
#     ('recommended', 'user', 18764487),
#     ('recommended', 'article', 'tcm:526-187302')]),
#   (1.0758504,
#    1.0622923,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 90913867),
#     ('recommended', 'article', 'tcm:526-191289')]),
#   (-0.26306805,
#    1.0631319,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('recommended', 'user', 3857212),
#     ('recommended', 'article', 'tcm:526-18025')]),
#   (-1.7502621,
#    1.0627667,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-655038'),
#     ('recommended', 'user', 93928051),
#     ('recommended', 'article', 'tcm:526-209028')]),
#   (-0.26989546,
#    1.0602846,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-259315'),
#     ('recommended', 'user', 15630763),
#     ('recommended', 'article', 'tcm:526-261006')]),
#   (-1.459958,
#    1.0517038,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-259315'),
#     ('also_response', 'related_article', 55),
#     ('also_response', 'article', 'tcm:526-346380')]),
#   (-0.8927521,
#    1.0626472,
#    [('self_loop', 'user', 21638664),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 39394802),
#     ('recommended', 'article', 'tcm:526-674187')])],
#  80330542: [(-0.6032454,
#    1.052725,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('also_response', 'related_article', 26),
#     ('also_response', 'article', 'tcm:526-237984')]),
#   (-0.9595027,
#    1.0665022,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-782343'),
#     ('recommended', 'user', 75379078),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (1.8017404,
#    1.0627918,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-149043'),
#     ('recommended', 'user', 10940177),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (-1.0259683,
#    1.0621338,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-655038'),
#     ('recommended', 'user', 9249629),
#     ('recommended', 'article', 'tcm:526-249921')]),
#   (-1.7453823,
#    1.0652548,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-674187'),
#     ('recommended', 'user', 8852855),
#     ('recommended', 'article', 'tcm:526-228258')]),
#   (2.0224078,
#    1.0646564,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-199040'),
#     ('recommended', 'user', 49161178),
#     ('recommended', 'article', 'tcm:526-681575')]),
#   (-1.8753192,
#    1.0699327,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-244935'),
#     ('recommended', 'user', 80365990),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (-1.9400971,
#    1.049787,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('also_response', 'related_article', 41),
#     ('also_response', 'article', 'tcm:526-258965')]),
#   (1.7980512,
#    1.0623055,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('recommended', 'user', 43668861),
#     ('recommended', 'article', 'tcm:526-276414')]),
#   (2.5522337,
#    1.0720799,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-18025'),
#     ('recommended', 'user', 68148402),
#     ('recommended', 'article', 'tcm:526-654768')]),
#   (0.9828392,
#    1.0604947,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-655038'),
#     ('also_response', 'related_article', 12),
#     ('also_response', 'article', 'tcm:526-388698')]),
#   (-1.2441825,
#    1.0623884,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-655038'),
#     ('recommended', 'user', 15630763),
#     ('recommended', 'article', 'tcm:526-164352')]),
#   (-0.51945275,
#    1.0617775,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('recommended', 'user', 15630763),
#     ('recommended', 'article', 'tcm:526-551763')]),
#   (-1.7972615,
#    1.0622286,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-261006'),
#     ('recommended', 'user', 64069272),
#     ('recommended', 'article', 'tcm:526-12167')]),
#   (2.242666,
#    1.0605437,
#    [('self_loop', 'user', 80330542),
#     ('recommended', 'article', 'tcm:526-784445'),
#     ('recommended', 'user', 19150580),
#     ('recommended', 'article', 'tcm:526-52560')])],
#  24151170: [(0.2544321,
#    1.0658343,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-22867'),
#     ('recommended', 'user', 27719425),
#     ('recommended', 'article', 'tcm:526-10838')]),
#   (-0.9759592,
#    1.0720333,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-22867'),
#     ('recommended', 'user', 76442608),
#     ('recommended', 'article', 'tcm:526-249921')]),
#   (-1.9868675,
#    1.0673634,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 16565679),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (-1.9309965,
#    1.0561146,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('also_response', 'related_article', 51),
#     ('also_response', 'article', 'tcm:526-259315')]),
#   (1.8968574,
#    1.0660512,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-674187'),
#     ('recommended', 'user', 90523021),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (-0.970832,
#    1.0689421,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 32240400),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (-1.8061303,
#    1.0529679,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('also_response', 'related_article', 38),
#     ('also_response', 'article', 'tcm:526-258965')]),
#   (-1.539628,
#    1.0666488,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-228258'),
#     ('recommended', 'user', 90913867),
#     ('recommended', 'article', 'tcm:526-684643')]),
#   (-1.8402408,
#    1.0623465,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-187302'),
#     ('recommended', 'user', 14394841),
#     ('recommended', 'article', 'tcm:526-199040')]),
#   (-0.06753094,
#    1.060618,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 30158480),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (-1.8595493,
#    1.0543053,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-244935'),
#     ('also_response', 'related_article', 54),
#     ('also_response', 'article', 'tcm:526-46242')]),
#   (1.5542814,
#    1.0636021,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-551763'),
#     ('recommended', 'user', 12488474),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (-0.72882336,
#    1.0637705,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-784445'),
#     ('recommended', 'user', 33906107),
#     ('recommended', 'article', 'tcm:526-40469')]),
#   (-1.151298,
#    1.0659876,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-653510'),
#     ('recommended', 'user', 10940177),
#     ('recommended', 'article', 'tcm:526-682379')]),
#   (-0.24607477,
#    1.0547552,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-653510'),
#     ('also_response', 'related_article', 25),
#     ('also_response', 'article', 'tcm:526-261006')]),
#   (1.6836444,
#    1.0662142,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 70342129),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (-0.30812952,
#    1.0649179,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-237984'),
#     ('recommended', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-688510')]),
#   (2.7296262,
#    1.0676225,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 899009),
#     ('recommended', 'article', 'tcm:526-654768')]),
#   (1.6877882,
#    1.0690011,
#    [('self_loop', 'user', 24151170),
#     ('recommended', 'article', 'tcm:526-249037'),
#     ('recommended', 'user', 55251130),
#     ('recommended', 'article', 'tcm:526-276414')])],
#  56395953: [(-1.0839769,
#    1.0634727,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-682576'),
#     ('recommended', 'user', 66260258),
#     ('recommended', 'article', 'tcm:526-682379')]),
#   (-1.3811616,
#    1.0685974,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-682576'),
#     ('recommended', 'user', 96738148),
#     ('recommended', 'article', 'tcm:526-684643')]),
#   (-1.4909711,
#    1.0675963,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-784445'),
#     ('recommended', 'user', 84785102),
#     ('recommended', 'article', 'tcm:526-209028')]),
#   (-0.21352501,
#    1.0622687,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-237984'),
#     ('recommended', 'user', 3202598),
#     ('recommended', 'article', 'tcm:526-688510')]),
#   (-0.62454253,
#    1.0633968,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-712788'),
#     ('recommended', 'user', 31443292),
#     ('recommended', 'article', 'tcm:526-674187')]),
#   (1.691012,
#    1.0651982,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-712788'),
#     ('recommended', 'user', 39419955),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (0.9115555,
#    1.0642363,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-704480'),
#     ('recommended', 'user', 58959607),
#     ('recommended', 'article', 'tcm:526-149043')]),
#   (2.609715,
#    1.068234,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-18025'),
#     ('recommended', 'user', 92051010),
#     ('recommended', 'article', 'tcm:526-654768')]),
#   (1.0826783,
#    1.0640293,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-655038'),
#     ('recommended', 'user', 61317971),
#     ('recommended', 'article', 'tcm:526-191289')]),
#   (-1.3197743,
#    1.0672245,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-10849'),
#     ('recommended', 'user', 31271084),
#     ('recommended', 'article', 'tcm:526-13782')]),
#   (1.4490969,
#    1.0649663,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-707567'),
#     ('recommended', 'user', 96388298),
#     ('recommended', 'article', 'tcm:526-153236')]),
#   (1.4265554,
#    1.0514377,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-258965'),
#     ('also_response', 'related_article', 10),
#     ('also_response', 'article', 'tcm:526-276414')]),
#   (1.8739265,
#    1.065639,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-244935'),
#     ('recommended', 'user', 32462819),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (6.608802,
#    1.0623572,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-70899'),
#     ('recommended', 'user', 69147387),
#     ('recommended', 'article', 'tcm:526-782343')]),
#   (-0.8648657,
#    1.0680071,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('recommended', 'user', 54242334),
#     ('recommended', 'article', 'tcm:526-249921')]),
#   (1.918768,
#    1.0508289,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-244935'),
#     ('also_response', 'related_article', 10),
#     ('also_response', 'article', 'tcm:526-248966')]),
#   (-1.0116909,
#    1.0623238,
#    [('self_loop', 'user', 56395953),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 57786997),
#     ('recommended', 'article', 'tcm:526-164352')])],
#  77816729: [(0.5989658,
#    1.0681351,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 18557857),
#     ('recommended', 'article', 'tcm:526-704480')]),
#   (-0.850779,
#    1.0653808,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-385364'),
#     ('recommended', 'user', 65362127),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (-0.2577114,
#    1.0676495,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 58747817),
#     ('recommended', 'article', 'tcm:526-688510')]),
#   (-1.889771,
#    1.0651501,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-187302'),
#     ('recommended', 'user', 16099560),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (-0.51011825,
#    1.0624989,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-209028'),
#     ('recommended', 'user', 92892173),
#     ('recommended', 'article', 'tcm:526-551763')]),
#   (-0.46194872,
#    1.0675768,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('recommended', 'user', 32975618),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (0.5447381,
#    1.0684841,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-40469'),
#     ('recommended', 'user', 84785102),
#     ('recommended', 'article', 'tcm:526-707567')]),
#   (-0.74876827,
#    1.0616721,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-684643'),
#     ('recommended', 'user', 71482759),
#     ('recommended', 'article', 'tcm:526-674187')]),
#   (-1.12108,
#    1.0651081,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 44703912),
#     ('recommended', 'article', 'tcm:526-164352')]),
#   (-0.12412439,
#    1.0699137,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-149043'),
#     ('recommended', 'user', 28753495),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (1.0124139,
#    1.0652627,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-684643'),
#     ('recommended', 'user', 59660030),
#     ('recommended', 'article', 'tcm:526-388698')]),
#   (-1.7289695,
#    1.0677772,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('recommended', 'user', 3833710),
#     ('recommended', 'article', 'tcm:526-199040')]),
#   (0.30107743,
#    1.0650625,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-249921'),
#     ('recommended', 'user', 29816351),
#     ('recommended', 'article', 'tcm:526-244935')]),
#   (-0.2345852,
#    1.0612127,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-682379'),
#     ('recommended', 'user', 7357379),
#     ('recommended', 'article', 'tcm:526-18025')]),
#   (-0.5689391,
#    1.061163,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-149043'),
#     ('recommended', 'user', 11946051),
#     ('recommended', 'article', 'tcm:526-70899')]),
#   (0.47615695,
#    1.0613953,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-149043'),
#     ('recommended', 'user', 64161485),
#     ('recommended', 'article', 'tcm:526-712788')]),
#   (2.1060622,
#    1.039874,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('also_response', 'related_article', 24),
#     ('recommended_together', 'article', 'tcm:526-681575')]),
#   (3.2745824,
#    1.0602819,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('recommended', 'user', 70364906),
#     ('recommended', 'article', 'tcm:526-784445')]),
#   (2.6161263,
#    1.060703,
#    [('self_loop', 'user', 77816729),
#     ('recommended', 'article', 'tcm:526-10849'),
#     ('recommended', 'user', 57907566),
#     ('recommended', 'article', 'tcm:526-654768')])],
#  75461182: [(-1.7200506,
#    1.0642852,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 13782094),
#     ('recommended', 'article', 'tcm:526-12167')]),
#   (1.1597905,
#    1.0614971,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-18025'),
#     ('recommended', 'user', 3957311),
#     ('recommended', 'article', 'tcm:526-492865')]),
#   (1.4930365,
#    1.0707093,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-149043'),
#     ('recommended', 'user', 28753495),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (1.4288657,
#    1.0599505,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-682379'),
#     ('recommended', 'user', 8082604),
#     ('recommended', 'article', 'tcm:526-153236')]),
#   (-0.25413597,
#    1.0619165,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-653510'),
#     ('recommended', 'user', 8703081),
#     ('recommended', 'article', 'tcm:526-688510')]),
#   (-1.4701364,
#    1.0663548,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-244935'),
#     ('recommended', 'user', 24123480),
#     ('recommended', 'article', 'tcm:526-228258')]),
#   (-1.6200314,
#    1.0503342,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-653510'),
#     ('also_response', 'related_article', 37),
#     ('also_response', 'article', 'tcm:526-258965')]),
#   (-0.64397395,
#    1.0641055,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-93195'),
#     ('recommended', 'user', 95157799),
#     ('recommended', 'article', 'tcm:526-674187')]),
#   (2.3564875,
#    1.0640132,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-249037'),
#     ('recommended', 'user', 96944088),
#     ('recommended', 'article', 'tcm:526-707527')]),
#   (1.957308,
#    1.0681828,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-199040'),
#     ('recommended', 'user', 3064052),
#     ('recommended', 'article', 'tcm:526-248966')]),
#   (-1.7794482,
#    1.0576355,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-418532'),
#     ('recommended', 'user', 10591106),
#     ('recommended', 'article', 'tcm:526-46242')]),
#   (-1.5270703,
#    1.057195,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-231792'),
#     ('recommended', 'user', 10591106),
#     ('recommended', 'article', 'tcm:526-385364')]),
#   (1.8740525,
#    1.0627596,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-231792'),
#     ('recommended', 'user', 28584938),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (0.6333409,
#    1.0609188,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 97362416),
#     ('recommended', 'article', 'tcm:526-707567')]),
#   (-0.85868526,
#    1.0640202,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 20992820),
#     ('recommended', 'article', 'tcm:526-249921')]),
#   (1.2737232,
#    1.0407006,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-276414'),
#     ('also_response', 'related_article', 24),
#     ('also_response', 'article', 'tcm:526-670542')]),
#   (-0.66222936,
#    1.0606031,
#    [('self_loop', 'user', 75461182),
#     ('recommended', 'article', 'tcm:526-276414'),
#     ('recommended', 'user', 12023267),
#     ('recommended', 'article', 'tcm:526-40469')])],
#  66966434: [(-1.1056796,
#    1.066724,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-704480'),
#     ('recommended', 'user', 12039627),
#     ('recommended', 'article', 'tcm:526-655038')]),
#   (-1.0278713,
#    1.069706,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-688510'),
#     ('recommended', 'user', 70342129),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (2.7716813,
#    1.0692744,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 28658409),
#     ('recommended', 'article', 'tcm:526-654768')]),
#   (-1.9994459,
#    1.0694165,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 57040101),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (-1.0765638,
#    1.0618632,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 93058502),
#     ('recommended', 'article', 'tcm:526-682379')]),
#   (-0.4798391,
#    1.0688349,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-704480'),
#     ('recommended', 'user', 24204102),
#     ('recommended', 'article', 'tcm:526-273898')]),
#   (-0.3717421,
#    1.0667876,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-191289'),
#     ('recommended', 'user', 32462819),
#     ('recommended', 'article', 'tcm:526-18025')]),
#   (0.5752717,
#    1.0682944,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-191289'),
#     ('recommended', 'user', 88418079),
#     ('recommended', 'article', 'tcm:526-707567')]),
#   (1.0210577,
#    1.0659091,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-674187'),
#     ('recommended', 'user', 77127264),
#     ('recommended', 'article', 'tcm:526-388698')]),
#   (1.619885,
#    1.0543846,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-209028'),
#     ('also_response', 'related_article', 54),
#     ('also_response', 'article', 'tcm:526-276414')]),
#   (-0.4899927,
#    1.068157,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-199040'),
#     ('recommended', 'user', 56349294),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (-0.103801906,
#    1.0676795,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 25033280),
#     ('recommended', 'article', 'tcm:526-249037')]),
#   (-1.9507278,
#    1.0625829,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-22867'),
#     ('recommended', 'user', 56845342),
#     ('recommended', 'article', 'tcm:526-46242')]),
#   (2.2454317,
#    1.066254,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-784445'),
#     ('recommended', 'user', 62005676),
#     ('recommended', 'article', 'tcm:526-248966')]),
#   (1.474484,
#    1.0426898,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-782343'),
#     ('also_response', 'related_article', 24),
#     ('also_response', 'article', 'tcm:526-80807')]),
#   (-0.1599881,
#    1.0506322,
#    [('self_loop', 'user', 66966434),
#     ('recommended', 'article', 'tcm:526-70899'),
#     ('also_response', 'related_article', 67),
#     ('also_response', 'article', 'tcm:526-656536')])],
#  82532248: [(-1.7978542,
#    1.0637672,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-653510'),
#     ('recommended', 'user', 95315927),
#     ('recommended', 'article', 'tcm:526-258965')]),
#   (-1.8011104,
#    1.0659463,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-653510'),
#     ('recommended', 'user', 3833710),
#     ('recommended', 'article', 'tcm:526-199040')]),
#   (2.0467489,
#    1.066368,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-22867'),
#     ('recommended', 'user', 2182320),
#     ('recommended', 'article', 'tcm:526-681575')]),
#   (0.5943143,
#    1.0664313,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 58501176),
#     ('recommended', 'article', 'tcm:526-707567')]),
#   (-1.5647899,
#    1.0644869,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-418532'),
#     ('recommended', 'user', 89952028),
#     ('recommended', 'article', 'tcm:526-239640')]),
#   (0.026476176,
#    1.061801,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 80399561),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (-1.9303547,
#    1.0504959,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('also_response', 'related_article', 25),
#     ('also_response', 'article', 'tcm:526-259315')]),
#   (-1.4303598,
#    1.0620764,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-388698'),
#     ('recommended', 'user', 8852855),
#     ('recommended', 'article', 'tcm:526-13782')]),
#   (-0.26313412,
#    1.0621362,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 15448959),
#     ('recommended', 'article', 'tcm:526-18025')]),
#   (-1.977752,
#    1.0627267,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-707527'),
#     ('recommended', 'user', 91189938),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (-1.6228069,
#    1.0635608,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-704480'),
#     ('recommended', 'user', 22451101),
#     ('recommended', 'article', 'tcm:526-209028')]),
#   (-0.2235694,
#    1.0575486,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 28716366),
#     ('recommended', 'article', 'tcm:526-261006')]),
#   (-0.45173177,
#    1.0652728,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-249921'),
#     ('recommended', 'user', 85962128),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (-1.4800307,
#    1.060536,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-346380'),
#     ('recommended', 'user', 8646481),
#     ('recommended', 'article', 'tcm:526-684643')]),
#   (-0.26467425,
#    1.0606261,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 77071928),
#     ('recommended', 'article', 'tcm:526-688510')]),
#   (-0.6045412,
#    1.058566,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-22867'),
#     ('recommended', 'user', 21036894),
#     ('recommended', 'article', 'tcm:526-70899')]),
#   (0.026102908,
#    1.0461549,
#    [('self_loop', 'user', 82532248),
#     ('recommended', 'article', 'tcm:526-249921'),
#     ('also_response', 'related_article', 64),
#     ('also_response', 'article', 'tcm:526-249037')])],
#  60356270: [(-0.9765638,
#    1.06443,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('recommended', 'user', 97711857),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (0.2519607,
#    1.0657979,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-18025'),
#     ('recommended', 'user', 68440663),
#     ('recommended', 'article', 'tcm:526-244935')]),
#   (-1.1159441,
#    1.0639861,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-18025'),
#     ('recommended', 'user', 3857212),
#     ('recommended', 'article', 'tcm:526-682379')]),
#   (-1.5383503,
#    1.0610768,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-224772'),
#     ('recommended', 'user', 19220501),
#     ('recommended', 'article', 'tcm:526-228258')]),
#   (3.4169304,
#    1.0484089,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-224772'),
#     ('also_response', 'related_article', 26),
#     ('also_response', 'article', 'tcm:526-784445')]),
#   (-0.04904466,
#    1.0647372,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-551763'),
#     ('recommended', 'user', 9696139),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (1.4943463,
#    1.063833,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-273898'),
#     ('recommended', 'user', 91189938),
#     ('recommended', 'article', 'tcm:526-153236')]),
#   (0.52405953,
#    1.0585058,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-704480'),
#     ('recommended', 'user', 56845342),
#     ('recommended', 'article', 'tcm:526-418532')]),
#   (-0.30369487,
#    1.0642301,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 533542),
#     ('recommended', 'article', 'tcm:526-688510')]),
#   (0.39689586,
#    1.0495354,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('also_response', 'related_article', 34),
#     ('also_response', 'article', 'tcm:526-10849')]),
#   (0.16039841,
#    1.0489149,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-199040'),
#     ('also_response', 'related_article', 41),
#     ('also_response', 'article', 'tcm:526-10838')]),
#   (-0.5754304,
#    1.0662001,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-199040'),
#     ('recommended', 'user', 13413877),
#     ('recommended', 'article', 'tcm:526-70899')]),
#   (-1.2561686,
#    1.0693009,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('recommended', 'user', 28753495),
#     ('recommended', 'article', 'tcm:526-346380')]),
#   (-1.9070289,
#    1.0658212,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-273898'),
#     ('recommended', 'user', 3833710),
#     ('recommended', 'article', 'tcm:526-12167')]),
#   (-2.045253,
#    1.0644605,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-187302'),
#     ('recommended', 'user', 86708778),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (-1.948513,
#    1.0486803,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-249037'),
#     ('also_response', 'related_article', 48),
#     ('also_response', 'article', 'tcm:526-259315')]),
#   (1.5537446,
#    1.0616714,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-712788'),
#     ('recommended', 'user', 50582333),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (-1.6502905,
#    1.0473588,
#    [('self_loop', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-149043'),
#     ('also_response', 'related_article', 64),
#     ('also_response', 'article', 'tcm:526-385364')])],
#  50953371: [(-0.53278106,
#    1.0644667,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 'tcm:526-153236'),
#     ('recommended', 'user', 91243393),
#     ('recommended', 'article', 'tcm:526-70899')]),
#   (-1.7819068,
#    1.0645983,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 13413877),
#     ('recommended', 'article', 'tcm:526-228258')]),
#   (-0.7189018,
#    1.0640002,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 'tcm:526-655038'),
#     ('recommended', 'user', 90685835),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (-0.19671603,
#    1.0641705,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 'tcm:526-209028'),
#     ('recommended', 'user', 14853630),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (1.608844,
#    1.068662,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 'tcm:526-653510'),
#     ('recommended', 'user', 63079092),
#     ('recommended', 'article', 'tcm:526-276414')]),
#   (-1.2756238,
#    1.0615461,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 'tcm:526-249921'),
#     ('recommended', 'user', 11887764),
#     ('recommended', 'article', 'tcm:526-682379')]),
#   (0.022847928,
#    1.0553663,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 93058502),
#     ('recommended', 'article', 'tcm:526-249037')]),
#   (-0.026917541,
#    1.0643591,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 'tcm:526-237984'),
#     ('recommended', 'user', 9696139),
#     ('recommended', 'article', 'tcm:526-244935')]),
#   (-1.4267508,
#    1.06519,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 'tcm:526-237984'),
#     ('recommended', 'user', 30548561),
#     ('recommended', 'article', 'tcm:526-684643')]),
#   (0.5557653,
#    1.0624449,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 'tcm:526-237984'),
#     ('recommended', 'user', 17137602),
#     ('recommended', 'article', 'tcm:526-418532')]),
#   (1.6245433,
#    1.0608017,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 'tcm:526-46242'),
#     ('recommended', 'user', 8117284),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (1.2892017,
#    1.057985,
#    [('self_loop', 'user', 50953371),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 60356270),
#     ('recommended', 'article', 'tcm:526-492865')])],
#  37478512: [(-1.2443851,
#    1.060073,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 97626415),
#     ('recommended', 'article', 'tcm:526-13782')]),
#   (0.06248588,
#    1.0610621,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-18025'),
#     ('recommended', 'user', 30700990),
#     ('recommended', 'article', 'tcm:526-249037')]),
#   (-0.64382887,
#    1.0645033,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 1103855),
#     ('recommended', 'article', 'tcm:526-70899')]),
#   (-0.541011,
#    1.0610952,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 83545651),
#     ('recommended', 'article', 'tcm:526-551763')]),
#   (-1.8249956,
#    1.0582123,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-385364'),
#     ('recommended', 'user', 8703081),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (0.34226725,
#    1.0568471,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-654768'),
#     ('also_response', 'related_article', 12),
#     ('also_response', 'article', 'tcm:526-12180')]),
#   (-0.9067551,
#    1.0470711,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-153236'),
#     ('also_response', 'related_article', 26),
#     ('also_response', 'article', 'tcm:526-249921')]),
#   (-1.03435,
#    1.0499208,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-237984'),
#     ('also_response', 'related_article', 51),
#     ('also_response', 'article', 'tcm:526-164352')]),
#   (-0.09336016,
#    1.0596448,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 51511421),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (2.3396406,
#    1.0587825,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-258965'),
#     ('recommended', 'user', 11853271),
#     ('recommended', 'article', 'tcm:526-52560')]),
#   (0.54960823,
#    1.0579535,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-258965'),
#     ('recommended', 'user', 64576502),
#     ('recommended', 'article', 'tcm:526-418532')]),
#   (1.5662189,
#    1.0617251,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-258965'),
#     ('recommended', 'user', 91243393),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (2.0295856,
#    1.0584888,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 63711636),
#     ('recommended', 'article', 'tcm:526-248966')]),
#   (-0.626743,
#    1.06182,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-149043'),
#     ('recommended', 'user', 30211627),
#     ('recommended', 'article', 'tcm:526-273898')]),
#   (0.48988172,
#    1.0547397,
#    [('self_loop', 'user', 37478512),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 4589648),
#     ('recommended', 'article', 'tcm:526-10849')])],
#  19695842: [(-0.8721574,
#    1.0620027,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 'tcm:526-784445'),
#     ('recommended', 'user', 17695510),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (1.7790481,
#    1.0616932,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 'tcm:526-704480'),
#     ('recommended', 'user', 53349469),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (-1.6223345,
#    1.0692203,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 54242334),
#     ('recommended', 'article', 'tcm:526-239640')]),
#   (0.5420328,
#    1.0618609,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 'tcm:526-22867'),
#     ('recommended', 'user', 96388298),
#     ('recommended', 'article', 'tcm:526-707567')]),
#   (-1.6277126,
#    1.0620743,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 'tcm:526-52560'),
#     ('recommended', 'user', 50582333),
#     ('recommended', 'article', 'tcm:526-228258')]),
#   (-0.57981473,
#    1.0612882,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 52156914),
#     ('recommended', 'article', 'tcm:526-70899')]),
#   (-1.6421528,
#    1.0588691,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('recommended', 'user', 7357379),
#     ('recommended', 'article', 'tcm:526-199040')]),
#   (-1.6801001,
#    1.054497,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 'tcm:526-784445'),
#     ('recommended', 'user', 93058502),
#     ('recommended', 'article', 'tcm:526-385364')]),
#   (-1.0600092,
#    1.0614345,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 'tcm:526-209028'),
#     ('recommended', 'user', 11887764),
#     ('recommended', 'article', 'tcm:526-655038')]),
#   (0.1650424,
#    1.0593406,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 'tcm:526-231792'),
#     ('recommended', 'user', 12039627),
#     ('recommended', 'article', 'tcm:526-187302')]),
#   (-0.15661968,
#    1.0385909,
#    [('self_loop', 'user', 19695842),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('also_response', 'related_article', 24),
#     ('also_response', 'article', 'tcm:526-656536')])],
#  36756635: [(-0.5790922,
#    1.0676398,
#    [('self_loop', 'user', 36756635),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('recommended', 'user', 88418079),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (1.5123482,
#    1.0509428,
#    [('self_loop', 'user', 36756635),
# ...
#     ('recommended', 'article', 'tcm:526-682379'),
#     ('recommended', 'user', 97772825),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (-0.92845374,
#    1.0626222,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 'tcm:526-684643'),
#     ('recommended', 'user', 8646481),
#     ('recommended', 'article', 'tcm:526-249921')]),
#   (1.587067,
#    1.0650952,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 'tcm:526-244935'),
#     ('recommended', 'user', 85584686),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (2.0284195,
#    1.0672592,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 'tcm:526-46242'),
#     ('recommended', 'user', 8646481),
#     ('recommended', 'article', 'tcm:526-248966')]),
#   (-1.0792549,
#    1.0659531,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 'tcm:526-784445'),
#     ('recommended', 'user', 91243393),
#     ('recommended', 'article', 'tcm:526-164352')]),
#   (2.3733397,
#    1.0623705,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 28921013),
#     ('recommended', 'article', 'tcm:526-707527')]),
#   (0.23064491,
#    1.0604774,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 'tcm:526-682379'),
#     ('recommended', 'user', 45544986),
#     ('recommended', 'article', 'tcm:526-187302')]),
#   (1.682204,
#    1.0645508,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 'tcm:526-244935'),
#     ('recommended', 'user', 61317971),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (-0.52699673,
#    1.0659609,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 13413877),
#     ('recommended', 'article', 'tcm:526-70899')]),
#   (1.4751728,
#    1.0532548,
#    [('self_loop', 'user', 95341607),
#     ('recommended', 'article', 'tcm:526-684643'),
#     ('also_response', 'related_article', 20),
#     ('also_response', 'article', 'tcm:526-276414')])],
#  4974617: [(-0.8028297,
#    1.0670313,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-149043'),
#     ('recommended', 'user', 47944661),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (3.2629511,
#    1.0641781,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-10849'),
#     ('recommended', 'user', 8646481),
#     ('recommended', 'article', 'tcm:526-784445')]),
#   (-1.4555118,
#    1.0653843,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-655038'),
#     ('recommended', 'user', 31574728),
#     ('recommended', 'article', 'tcm:526-209028')]),
#   (2.2786078,
#    1.0699061,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-149043'),
#     ('recommended', 'user', 25151468),
#     ('recommended', 'article', 'tcm:526-52560')]),
#   (-0.13164946,
#    1.0677809,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 67108585),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (1.8436041,
#    1.0667019,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-22867'),
#     ('recommended', 'user', 6567408),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (2.6964712,
#    1.0648152,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-224772'),
#     ('recommended', 'user', 65703510),
#     ('recommended', 'article', 'tcm:526-654768')]),
#   (-0.9158576,
#    1.0623819,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-224772'),
#     ('recommended', 'user', 63423394),
#     ('recommended', 'article', 'tcm:526-249921')]),
#   (-1.6449906,
#    1.064294,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-418532'),
#     ('recommended', 'user', 33226655),
#     ('recommended', 'article', 'tcm:526-199040')]),
#   (0.0040608062,
#    1.0639973,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('recommended', 'user', 57907566),
#     ('recommended', 'article', 'tcm:526-249037')]),
#   (-1.5766464,
#    1.067307,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-191289'),
#     ('recommended', 'user', 8779806),
#     ('recommended', 'article', 'tcm:526-228258')]),
#   (-0.25282446,
#    1.0419307,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-187302'),
#     ('also_response', 'related_article', 24),
#     ('recommended_together', 'article', 'tcm:526-261006')]),
#   (-1.7411064,
#    1.0507087,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-231792'),
#     ('also_response', 'related_article', 48),
#     ('also_response', 'article', 'tcm:526-259315')]),
#   (-1.3871992,
#    1.0639582,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-653510'),
#     ('recommended', 'user', 8646481),
#     ('recommended', 'article', 'tcm:526-684643')]),
#   (-0.6332537,
#    1.0662112,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 92051010),
#     ('recommended', 'article', 'tcm:526-70899')]),
#   (1.2513672,
#    1.0635148,
#    [('self_loop', 'user', 4974617),
#     ('recommended', 'article', 'tcm:526-153236'),
#     ('recommended', 'user', 90734909),
#     ('recommended', 'article', 'tcm:526-492865')])],
#  53218502: [(0.4502928,
#    1.0523713,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-224772'),
#     ('also_response', 'related_article', 25),
#     ('also_response', 'article', 'tcm:526-712788')]),
#   (-1.2053559,
#    1.0651376,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-224772'),
#     ('recommended', 'user', 3857212),
#     ('recommended', 'article', 'tcm:526-682379')]),
#   (-0.79705477,
#    1.0646402,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-46242'),
#     ('recommended', 'user', 8646481),
#     ('recommended', 'article', 'tcm:526-674187')]),
#   (-1.5582125,
#    1.0670489,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-248966'),
#     ('recommended', 'user', 32240400),
#     ('recommended', 'article', 'tcm:526-209028')]),
#   (-1.5049502,
#    1.042014,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-653510'),
#     ('also_response', 'related_article', 24),
#     ('also_response', 'article', 'tcm:526-684643')]),
#   (1.8903385,
#    1.0634466,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('recommended', 'user', 35364364),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (-0.4737864,
#    1.0644827,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-682576'),
#     ('recommended', 'user', 53067043),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (0.587615,
#    1.0643947,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 58959607),
#     ('recommended', 'article', 'tcm:526-704480')]),
#   (-1.8446589,
#    1.0629219,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-784445'),
#     ('recommended', 'user', 93662097),
#     ('recommended', 'article', 'tcm:526-12167')]),
#   (-1.0030996,
#    1.0593811,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 9249629),
#     ('recommended', 'article', 'tcm:526-249921')]),
#   (1.4308667,
#    1.0655146,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-688510'),
#     ('recommended', 'user', 5802402),
#     ('recommended', 'article', 'tcm:526-153236')]),
#   (-1.1410074,
#    1.066799,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-10849'),
#     ('recommended', 'user', 92051010),
#     ('recommended', 'article', 'tcm:526-164352')]),
#   (0.13345143,
#    1.0580429,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 14394841),
#     ('recommended', 'article', 'tcm:526-187302')]),
#   (-0.67484945,
#    1.0520813,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('also_response', 'related_article', 17),
#     ('also_response', 'article', 'tcm:526-273898')]),
#   (2.3607824,
#    1.067858,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-93195'),
#     ('recommended', 'user', 1716577),
#     ('recommended', 'article', 'tcm:526-52560')]),
#   (2.386619,
#    1.0498484,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-385364'),
#     ('also_response', 'related_article', 25),
#     ('also_response', 'article', 'tcm:526-707527')]),
#   (0.14214914,
#    1.0500543,
#    [('self_loop', 'user', 53218502),
#     ('recommended', 'article', 'tcm:526-385364'),
#     ('also_response', 'related_article', 10),
#     ('also_response', 'article', 'tcm:526-10838')])],
#  5723995: [(-0.75223017,
#    1.0609331,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 45511368),
#     ('recommended', 'article', 'tcm:526-674187')]),
#   (1.3698863,
#    1.0602624,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-209028'),
#     ('recommended', 'user', 70186693),
#     ('recommended', 'article', 'tcm:526-492865')]),
#   (0.007534207,
#    1.0647864,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-228258'),
#     ('recommended', 'user', 74756750),
#     ('recommended', 'article', 'tcm:526-249037')]),
#   (-1.6123813,
#    1.0623664,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-261006'),
#     ('recommended', 'user', 10940177),
#     ('recommended', 'article', 'tcm:526-199040')]),
#   (0.5290034,
#    1.0642581,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-149043'),
#     ('recommended', 'user', 19475507),
#     ('recommended', 'article', 'tcm:526-418532')]),
#   (2.7137592,
#    1.0677487,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-70899'),
#     ('recommended', 'user', 25151468),
#     ('recommended', 'article', 'tcm:526-654768')]),
#   (-1.646636,
#    1.0701119,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-684643'),
#     ('recommended', 'user', 63079092),
#     ('recommended', 'article', 'tcm:526-239640')]),
#   (-0.14500968,
#    1.0674646,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-684643'),
#     ('recommended', 'user', 31271084),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (1.6263597,
#    1.0672126,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 86708778),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (-0.67145807,
#    1.042514,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('also_response', 'related_article', 24),
#     ('recommended_together', 'article', 'tcm:526-273898')]),
#   (-1.0833318,
#    1.0617541,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('recommended', 'user', 11946051),
#     ('recommended', 'article', 'tcm:526-164352')]),
#   (2.3820193,
#    1.0732818,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-782343'),
#     ('recommended', 'user', 72137232),
#     ('recommended', 'article', 'tcm:526-707527')]),
#   (2.156946,
#    1.0679907,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-191289'),
#     ('recommended', 'user', 45342167),
#     ('recommended', 'article', 'tcm:526-681575')]),
#   (1.5334089,
#    1.0640996,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-191289'),
#     ('recommended', 'user', 90523021),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (-0.5688613,
#    1.0605985,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-248966'),
#     ('also_response', 'related_article', 23),
#     ('also_response', 'article', 'tcm:526-551763')]),
#   (-0.2157893,
#    1.0636387,
#    [('self_loop', 'user', 5723995),
#     ('recommended', 'article', 'tcm:526-10787'),
#     ('recommended', 'user', 95157799),
#     ('recommended', 'article', 'tcm:526-18025')])],
#  49710303: [(2.0176082,
#    1.0660491,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-199040'),
#     ('recommended', 'user', 3833710),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (1.7790531,
#    1.064618,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-93195'),
#     ('recommended', 'user', 58959607),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (-1.9108597,
#    1.0493015,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('also_response', 'related_article', 13),
#     ('also_response', 'article', 'tcm:526-258965')]),
#   (-1.110089,
#    1.0618159,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 59427824),
#     ('recommended', 'article', 'tcm:526-655038')]),
#   (-0.24425787,
#    1.0407887,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('also_response', 'related_article', 24),
#     ('recommended_together', 'article', 'tcm:526-261006')]),
#   (-2.3746276,
#    1.0644217,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 53349469),
#     ('recommended', 'article', 'tcm:526-695181')]),
#   (-1.1468401,
#    1.0676811,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 61445492),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (-2.1624863,
#    1.0649973,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 91069521),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (-2.1583633,
#    1.0494986,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-248966'),
#     ('also_response', 'related_article', 48),
#     ('also_response', 'article', 'tcm:526-259315')]),
#   (0.5410196,
#    1.0663937,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-388698'),
#     ('recommended', 'user', 58501176),
#     ('recommended', 'article', 'tcm:526-712788')]),
#   (1.7109274,
#    1.0612837,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-684643'),
#     ('recommended', 'user', 11853271),
#     ('recommended', 'article', 'tcm:526-492865')]),
#   (-2.0243132,
#    1.0599184,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-704480'),
#     ('recommended', 'user', 7357379),
#     ('recommended', 'article', 'tcm:526-46242')]),
#   (-1.0558342,
#    1.048006,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-682379'),
#     ('also_response', 'related_article', 27),
#     ('also_response', 'article', 'tcm:526-249921')]),
#   (-0.87413704,
#    1.0601116,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-52560'),
#     ('recommended', 'user', 31712138),
#     ('recommended', 'article', 'tcm:526-674187')]),
#   (-1.2699008,
#    1.0678095,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-52560'),
#     ('recommended', 'user', 24123480),
#     ('recommended', 'article', 'tcm:526-164352')]),
#   (-0.024277939,
#    1.0633774,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-93195'),
#     ('recommended', 'user', 88418079),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (-0.15103255,
#    1.0473505,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-93195'),
#     ('also_response', 'related_article', 26),
#     ('also_response', 'article', 'tcm:526-656536')]),
#   (-1.4112406,
#    1.0505588,
#    [('self_loop', 'user', 49710303),
#     ('recommended', 'article', 'tcm:526-10849'),
#     ('also_response', 'related_article', 55),
#     ('also_response', 'article', 'tcm:526-346380')])]}
