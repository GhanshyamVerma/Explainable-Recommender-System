# %%
# !ls
# Out:
# LICENSE    __pycache__	load_data.py  model.py	      tucker.png
# README.md  data		main.py       run_cmds.ipynb

# %%
# !python ../process_kg.py --kg_path ../KG_nt/KG_dep_parsing_100terms.nt --out_path data/KG_dep_parsing_100terms
# Out:
# Current working directory :  /root/recsys/recsys/TuckER

# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --dataset KG_dep_parsing_100terms --num_iterations 300 --batch_size 128 --lr 0.05 --dr 1.0 --edim 300 --rdim 300 --input_dropout 0.3 --hidden_dropout1 0.4 --hidden_dropout2 0.5 --label_smoothing 0.1
# Out:
# Training the TuckER model...
# Number of training data points: 512
# Starting training...
# 1
# 0.7023282051086426
# 0.9063598116238912
# Validation:
# Number of data points: 64
# Hits @10: 0.0625
# Hits @3: 0.03125
# Hits @1: 0.0
# Mean rank: 84.984375
# Mean reciprocal rank: 0.03469678652733601
# 2
# 0.06328821182250977
# 0.5054413378238678
# Validation:
# Number of data points: 64
# Hits @10: 0.15625
# Hits @3: 0.0625
# Hits @1: 0.03125
# Mean rank: 67.0
# Mean reciprocal rank: 0.07473638445945056
# Test:
# Number of data points: 66
# Hits @10: 0.3333333333333333
# Hits @3: 0.18181818181818182
# Hits @1: 0.015151515151515152
# Mean rank: 60.333333333333336
# Mean reciprocal rank: 0.12208545344266514
# 0.011684894561767578
# 3
# 0.05795454978942871
# 0.18409375349680582
# Validation:
# Number of data points: 64
# Hits @10: 0.1875
# Hits @3: 0.15625
# Hits @1: 0.09375
# Mean rank: 62.21875
# Mean reciprocal rank: 0.14189508826650268
# 4
# 0.05787801742553711
# 0.11096342653036118
# ...

# %%
# !ls

# %%
# !mv opendialkg_entity_embeddings.txt ../outputs/KGs/KG_dep_parsing_100terms.txt
